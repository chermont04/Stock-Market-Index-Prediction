# %% [markdown]
# ## 1. importing packages

# %%
import pandas as pd
import pandas_ta as ta
import numpy as np
import datetime as dt
import pandas_datareader as web
from tqdm import tqdm
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import matplotlib.ticker as ticker

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate
from tensorflow.keras.callbacks import History
from tensorflow.keras import optimizers

# %% [markdown]
# ## 2. overall configurations

# %%
# %matplotlib inline


tqdm.pandas()
sns.set(style='whitegrid',palette='muted')
rcParams['figure.figsize'] = 14, 10

# %% [markdown]
# ## 3. Getting the Data

# %%
import yfinance as yf
ticket = yf.Ticker('BOVA11.SA')
start = dt.datetime(2009, 1, 2) # First register data
end = dt.datetime(dt.datetime.now().year,dt.datetime.now().month,dt.datetime.now().day - 1)

bova11 = ticket.history(interval= '1d', start = start, end = end).reset_index()
bova11
# Out:
#                           Date        Open        High         Low  \
# 0    2009-01-02 00:00:00-02:00   38.279999   40.320000   37.939999
# 1    2009-01-05 00:00:00-02:00   40.200001   42.000000   39.700001
# 2    2009-01-06 00:00:00-02:00   42.060001   42.320000   41.549999
# 3    2009-01-07 00:00:00-02:00   41.750000   41.770000   40.450001
# 4    2009-01-08 00:00:00-02:00   40.150002   42.200001   40.150002
# ...                        ...         ...         ...         ...
# 3459 2022-12-12 00:00:00-03:00  103.750000  103.970001  100.300003
# 3460 2022-12-13 00:00:00-03:00  102.260002  103.730003  100.019997
# 3461 2022-12-14 00:00:00-03:00   99.300003  101.160004   98.300003
# 3462 2022-12-15 00:00:00-03:00   99.940002  102.199997   99.550003
# 3463 2022-12-16 00:00:00-03:00  100.449997  100.639999   98.809998
#
#            Close    Volume  Dividends  Stock Splits
# 0      40.320000    119900          0             0
# 1      42.000000    341700          0             0
# 2      42.320000    178300          0             0
# 3      40.639999     73400          0             0
# 4      42.200001    195300          0             0
# ...          ...       ...        ...           ...
# 3459  101.800003  12417047          0             0
# 3460  100.300003  16354218          0             0
# 3461  100.699997  15092220          0             0
# 3462  100.500000  12770355          0             0
# 3463   99.400002  12353740          0             0
#
# [3464 rows x 8 columns]

# %%
len(bova11)
# Out:
# 3464

# %% [markdown]
# ## 4. Pre-processing

# %% [markdown]
# Adjust the columns name and type

# %%
bova11.columns = bova11.columns.str.lower()

# %%
bova11.date = pd.to_datetime(bova11.date)

# %%
bova11.isna().sum()
# Out:
# date            0
# open            0
# high            0
# low             0
# close           0
# volume          0
# dividends       0
# stock splits    0
# dtype: int64

# %% [markdown]
# Removing rows with volume 0

# %%
bova11 = bova11.loc[(bova11.volume != 0)].reset_index()
bova11.drop(columns='index', axis = 1, inplace = True)
bova11
# Out:
#                           date        open        high         low  \
# 0    2009-01-02 00:00:00-02:00   38.279999   40.320000   37.939999
# 1    2009-01-05 00:00:00-02:00   40.200001   42.000000   39.700001
# 2    2009-01-06 00:00:00-02:00   42.060001   42.320000   41.549999
# 3    2009-01-07 00:00:00-02:00   41.750000   41.770000   40.450001
# 4    2009-01-08 00:00:00-02:00   40.150002   42.200001   40.150002
# ...                        ...         ...         ...         ...
# 3366 2022-12-12 00:00:00-03:00  103.750000  103.970001  100.300003
# 3367 2022-12-13 00:00:00-03:00  102.260002  103.730003  100.019997
# 3368 2022-12-14 00:00:00-03:00   99.300003  101.160004   98.300003
# 3369 2022-12-15 00:00:00-03:00   99.940002  102.199997   99.550003
# 3370 2022-12-16 00:00:00-03:00  100.449997  100.639999   98.809998
#
#            close    volume  dividends  stock splits
# 0      40.320000    119900          0             0
# 1      42.000000    341700          0             0
# 2      42.320000    178300          0             0
# 3      40.639999     73400          0             0
# 4      42.200001    195300          0             0
# ...          ...       ...        ...           ...
# 3366  101.800003  12417047          0             0
# 3367  100.300003  16354218          0             0
# 3368  100.699997  15092220          0             0
# 3369  100.500000  12770355          0             0
# 3370   99.400002  12353740          0             0
#
# [3371 rows x 8 columns]

# %% [markdown]
# Sorting the data by date

# %%
bova11 = bova11.sort_values(by='date').reset_index(drop=True)

# %% [markdown]
# Adding a column with the previous close value

# %%
bova11["prev_close"] = bova11.shift(1)["close"]

# %%
bova11.head()
# Out:
#                        date       open       high        low      close  \
# 0 2009-01-02 00:00:00-02:00  38.279999  40.320000  37.939999  40.320000
# 1 2009-01-05 00:00:00-02:00  40.200001  42.000000  39.700001  42.000000
# 2 2009-01-06 00:00:00-02:00  42.060001  42.320000  41.549999  42.320000
# 3 2009-01-07 00:00:00-02:00  41.750000  41.770000  40.450001  40.639999
# 4 2009-01-08 00:00:00-02:00  40.150002  42.200001  40.150002  42.200001
#
#    volume  dividends  stock splits  prev_close
# 0  119900          0             0         NaN
# 1  341700          0             0   40.320000
# 2  178300          0             0   42.000000
# 3   73400          0             0   42.320000
# 4  195300          0             0   40.639999

# %% [markdown]
# Adding the close difference between dates

# %%
bova11["close_change"]= bova11.progress_apply(
    lambda row: 0 if np.isnan(row.prev_close) else row.close - row.prev_close,
    axis = 1
)
# Out:
# 100%|██████████| 3371/3371 [00:00<00:00, 12220.43it/s]

# %%
bova11.head()
# Out:
#                        date       open       high        low      close  \
# 0 2009-01-02 00:00:00-02:00  38.279999  40.320000  37.939999  40.320000
# 1 2009-01-05 00:00:00-02:00  40.200001  42.000000  39.700001  42.000000
# 2 2009-01-06 00:00:00-02:00  42.060001  42.320000  41.549999  42.320000
# 3 2009-01-07 00:00:00-02:00  41.750000  41.770000  40.450001  40.639999
# 4 2009-01-08 00:00:00-02:00  40.150002  42.200001  40.150002  42.200001
#
#    volume  dividends  stock splits  prev_close  close_change
# 0  119900          0             0         NaN      0.000000
# 1  341700          0             0   40.320000      1.680000
# 2  178300          0             0   42.000000      0.320000
# 3   73400          0             0   42.320000     -1.680000
# 4  195300          0             0   40.639999      1.560001

# %% [markdown]
# Checking the dataseries over time

# %%
daily_closing = bova11[['date','close']]
daily_closing = daily_closing.set_index('date')
ax = daily_closing.plot()
plt.title('Valor de fechamento do BOVA11 ao longo dos anos')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R${x:,.2f}"))

# %% [markdown]
# #### Feature Engineering
# Add auxiliar columns that can improve our model, like moving averages,standard deviation, techinical indicators and others
# Let's add:
# - Moving_average for 3, 10, 30 and 60 days
# - Standard deviation for 7, 30 and 60 days
# - Bollinger limits for Upper and lowers 3, 30 and 60
# - Add RSI indicator

# %%
# Adding move Averages columns
bova11['ma_3d'] = bova11['close'].rolling(3, center = True, min_periods=1).mean()
bova11['ma_10d'] = bova11['close'].rolling(10, center = True,min_periods=1).mean()
bova11['ma_30d'] = bova11['close'].rolling(30, center=True, min_periods=1).mean()
bova11['ma_60d'] = bova11['close'].rolling(60, center = True, min_periods = 1).mean()

# %%
# Adding standard deviation columns
bova11['std_7'] = bova11['close'].rolling(7, center = True, min_periods = 1).std()
bova11['std_30'] = bova11['close'].rolling(30, center = True, min_periods = 1).std()
bova11['std_60'] = bova11['close'].rolling(60, center = True, min_periods = 1).std()

# %%
# Adding the bollinger bands
bova11['upper3'] = bova11['ma_3d'] + 2*bova11['close'].rolling(3, center = True, min_periods = 1).std()
bova11['lower3'] = bova11['ma_3d'] - 2*bova11['close'].rolling(3, center = True, min_periods = 1).std()

bova11['upper30'] = bova11['ma_30d'] + 2*bova11['std_30']
bova11['lower30'] = bova11['ma_30d'] - 2*bova11['std_30']

bova11['upper60'] = bova11['ma_60d'] + 2*bova11['std_60']
bova11['lower60'] = bova11['ma_60d'] - 2*bova11['std_60']

# %%
# Adding tecnical indicator RSI
bova11['RSI'] = ta.rsi(bova11['close'], length = 15)

# %%
moving_avg = bova11[['date','ma_30d']]
moving_avg = moving_avg.set_index('date')
ax = moving_avg.plot()
plt.title('Valor de fechamento do IBOVESPA ao longo dos anos')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R${x:,.2f}"))

# %% [markdown]
# Select the features and the predict columns

# %%
bova11.drop(['date', 'volume', 'dividends', 'stock splits', 'prev_close'],
            axis = 1,
           inplace = True)

# %%
bova11
# Out:
#             open        high         low       close  close_change  \
# 15     37.009998   38.430000   36.799999   38.080002     -0.160000
# 16     38.060001   39.500000   37.910000   39.000000      0.919998
# 17     38.509998   38.990002   38.320000   38.990002     -0.009998
# 18     39.369999   40.900002   39.369999   40.900002      1.910000
# 19     39.740002   40.810001   39.369999   39.599998     -1.300003
# ...          ...         ...         ...         ...           ...
# 3366  103.750000  103.970001  100.300003  101.800003     -2.099998
# 3367  102.260002  103.730003  100.019997  100.300003     -1.500000
# 3368   99.300003  101.160004   98.300003  100.699997      0.399994
# 3369   99.940002  102.199997   99.550003  100.500000     -0.199997
# 3370  100.449997  100.639999   98.809998   99.400002     -1.099998
#
#            ma_3d      ma_10d      ma_30d      ma_60d     std_7    std_30  \
# 15     38.440001   39.109001   40.216334   39.769778  0.918000  1.394817
# 16     38.690001   39.120000   40.267334   39.750870  0.944667  1.426353
# 17     39.630001   39.125000   40.267000   39.731702  0.954819  1.425935
# 18     39.830001   39.226000   40.189667   39.726875  0.866391  1.372670
# 19     40.033333   39.381001   40.168000   39.716123  0.700044  1.370445
# ...          ...         ...         ...         ...       ...       ...
# 3366  102.000003  102.813000  104.691000  106.932000  2.042764  2.810232
# 3367  100.933334  102.500000  104.617894  106.841765  1.713152  2.867634
# 3368  100.500000  101.970000  104.592777  106.655151  1.573531  2.948619
# 3369  100.199999  101.452858  104.554705  106.483437  0.861975  3.034804
# 3370   99.950001  101.100001  104.326875  106.279355  0.573729  2.980401
#
#         std_60      upper3      lower3     upper30    lower30     upper60  \
# 15    1.612324   39.423056   37.456947   43.005967  37.426700   42.994426
# 16    1.599458   39.746598   37.633404   43.120039  37.414628   42.949786
# 17    1.587425   41.829729   37.430273   43.118870  37.415130   42.906553
# 18    1.570803   41.781103   37.878898   42.935008  37.444326   42.868481
# 19    1.556176   41.534447   38.532219   42.908891  37.427110   42.828474
# ...        ...         ...         ...         ...        ...         ...
# 3366  3.899315  105.616629   98.383376  110.311464  99.070535  114.730630
# 3367  3.920687  102.486827   99.379842  110.353162  98.882627  114.683138
# 3368  3.825064  100.899994  100.100006  110.490016  98.695538  114.305280
# 3369  3.754820  101.599996   98.800003  110.624313  98.485098  113.993077
# 3370  3.631998  101.505634   98.394368  110.287677  98.366072  113.543351
#
#         lower60        RSI    target
# 15    36.545130  37.055643  1.070004
# 16    36.551954  44.613302  0.939999
# 17    36.556852  44.551016  0.480003
# 18    36.585269  56.874437  1.530003
# 19    36.603771  48.942204 -0.140003
# ...         ...        ...       ...
# 3366  99.133370  38.163946 -1.949997
# 3367  99.000391  35.651080 -1.959999
# 3368  99.005022  36.839277  1.399994
# 3369  98.973797  36.478435  0.559998
# 3370  99.015358  34.487751 -1.049995
#
# [3356 rows x 20 columns]

# %%
bova11['target'] = bova11.close - bova11.open
#bova11['targetClass'] = [1 if bova11.target[i] > 0 else 0 for i in range(len(bova11))]
bova11['targetNextClose'] = bova11['close'].shift(-1)

# %%
bova11
# Out:
#             open        high         low       close  close_change  \
# 15     37.009998   38.430000   36.799999   38.080002     -0.160000
# 16     38.060001   39.500000   37.910000   39.000000      0.919998
# 17     38.509998   38.990002   38.320000   38.990002     -0.009998
# 18     39.369999   40.900002   39.369999   40.900002      1.910000
# 19     39.740002   40.810001   39.369999   39.599998     -1.300003
# ...          ...         ...         ...         ...           ...
# 3366  103.750000  103.970001  100.300003  101.800003     -2.099998
# 3367  102.260002  103.730003  100.019997  100.300003     -1.500000
# 3368   99.300003  101.160004   98.300003  100.699997      0.399994
# 3369   99.940002  102.199997   99.550003  100.500000     -0.199997
# 3370  100.449997  100.639999   98.809998   99.400002     -1.099998
#
#            ma_3d      ma_10d      ma_30d      ma_60d     std_7  ...    std_60  \
# 15     38.440001   39.109001   40.216334   39.769778  0.918000  ...  1.612324
# 16     38.690001   39.120000   40.267334   39.750870  0.944667  ...  1.599458
# 17     39.630001   39.125000   40.267000   39.731702  0.954819  ...  1.587425
# 18     39.830001   39.226000   40.189667   39.726875  0.866391  ...  1.570803
# 19     40.033333   39.381001   40.168000   39.716123  0.700044  ...  1.556176
# ...          ...         ...         ...         ...       ...  ...       ...
# 3366  102.000003  102.813000  104.691000  106.932000  2.042764  ...  3.899315
# 3367  100.933334  102.500000  104.617894  106.841765  1.713152  ...  3.920687
# 3368  100.500000  101.970000  104.592777  106.655151  1.573531  ...  3.825064
# 3369  100.199999  101.452858  104.554705  106.483437  0.861975  ...  3.754820
# 3370   99.950001  101.100001  104.326875  106.279355  0.573729  ...  3.631998
#
#           upper3      lower3     upper30    lower30     upper60    lower60  \
# 15     39.423056   37.456947   43.005967  37.426700   42.994426  36.545130
# 16     39.746598   37.633404   43.120039  37.414628   42.949786  36.551954
# 17     41.829729   37.430273   43.118870  37.415130   42.906553  36.556852
# 18     41.781103   37.878898   42.935008  37.444326   42.868481  36.585269
# 19     41.534447   38.532219   42.908891  37.427110   42.828474  36.603771
# ...          ...         ...         ...        ...         ...        ...
# 3366  105.616629   98.383376  110.311464  99.070535  114.730630  99.133370
# 3367  102.486827   99.379842  110.353162  98.882627  114.683138  99.000391
# 3368  100.899994  100.100006  110.490016  98.695538  114.305280  99.005022
# 3369  101.599996   98.800003  110.624313  98.485098  113.993077  98.973797
# 3370  101.505634   98.394368  110.287677  98.366072  113.543351  99.015358
#
#             RSI    target  targetNextClose
# 15    37.055643  1.070004        39.000000
# 16    44.613302  0.939999        38.990002
# 17    44.551016  0.480003        40.900002
# 18    56.874437  1.530003        39.599998
# 19    48.942204 -0.140003        39.599998
# ...         ...       ...              ...
# 3366  38.163946 -1.949997       100.300003
# 3367  35.651080 -1.959999       100.699997
# 3368  36.839277  1.399994       100.500000
# 3369  36.478435  0.559998        99.400002
# 3370  34.487751 -1.049995              NaN
#
# [3356 rows x 21 columns]

# %%
bova11.dropna(inplace = True)

# %%
scaler = MinMaxScaler(feature_range = (-1, 1))
bova11_scaled = scaler.fit_transform(bova11)
print(bova11_scaled)
# Out:
# [[-0.41052802 -0.95937954 -0.97594966 ... -0.34158244 -0.812735
#   -0.94288915]
#  [-0.39380423 -0.93549828 -0.95100022 ... -0.1145866  -0.81635782
#   -0.94311308]
#  [-0.38663696 -0.9468809  -0.94178467 ... -0.11645738 -0.82917641
#   -0.90033593]
#  ...
#  [ 0.62873302  0.49804714  0.44504377 ... -0.3837688  -0.89717146
#    0.43896969]
#  [ 0.58158801  0.44068748  0.40638354 ... -0.34808104 -0.80353922
#    0.43449048]
#  [ 0.59178152  0.46389903  0.43447974 ... -0.358919   -0.82694723
#    0.40985445]]

# %% [markdown]
# Select the features and prediction target columns

# %%
backcandles = 100
X = []
for j in range(19): # range is the number of feature columns you will use
    X.append([])
    for i in range(backcandles, bova11_scaled.shape[0]):
        X[j].append(bova11_scaled[i-backcandles:i, j])

#move axis from 0 to position 2
X = np.moveaxis(X, [0], [2])

X, yi = np.array(X), np.array(bova11_scaled[backcandles:, -1]) # Chosing the last column as the pred. target
y = np.reshape(yi, (len(yi), 1))

X.shape, y.shape
# Out:
# ((3255, 100, 19), (3255, 1))

# %% [markdown]
# Split the train and test data

# %%
splitlimit = int(len(X) * 0.9)
X_train, X_test = X[:splitlimit], X[splitlimit+1:]
y_train, y_test = y[:splitlimit], y[splitlimit+1:]

# %% [markdown]
# ### 4. Creating the model

# %%
def create_lstm_model(backcandles, num_features):
    lstm_input = Input(shape = (backcandles, num_features), name = 'lstm_input')
    inputs = LSTM(150, name = 'first_layer')(lstm_input)
    inputs = Dense(1, name = 'dense_layer')(inputs)
    output = Activation('linear', name = 'output')(inputs)
    model = Model(inputs = lstm_input, outputs = output)
    adam = optimizers.Adam()
    model.compile(optimizer=adam, loss = 'mse')
    return model

# %%
model = create_lstm_model(100, 19)
model.fit(x = X_train, y = y_train, batch_size = 15, epochs = 30, shuffle = True, validation_split = 0.1)
# Out:
# Epoch 1/30
# 176/176 [==============================] - 24s 88ms/step - loss: 0.0060 - val_loss: 0.0020
# Epoch 2/30
# 176/176 [==============================] - 14s 80ms/step - loss: 9.0561e-04 - val_loss: 0.0017
# Epoch 3/30
# 176/176 [==============================] - 18s 100ms/step - loss: 8.6838e-04 - val_loss: 0.0029
# Epoch 4/30
# 176/176 [==============================] - 18s 102ms/step - loss: 8.9619e-04 - val_loss: 0.0017
# Epoch 5/30
# 176/176 [==============================] - 18s 103ms/step - loss: 7.9808e-04 - val_loss: 0.0024
# Epoch 6/30
# 176/176 [==============================] - 16s 90ms/step - loss: 8.5785e-04 - val_loss: 0.0024
# Epoch 7/30
# 176/176 [==============================] - 15s 87ms/step - loss: 8.1988e-04 - val_loss: 0.0016
# Epoch 8/30
# 176/176 [==============================] - 15s 86ms/step - loss: 7.8058e-04 - val_loss: 0.0026
# Epoch 9/30
# 176/176 [==============================] - 16s 93ms/step - loss: 8.3226e-04 - val_loss: 0.0015
# Epoch 10/30
# 176/176 [==============================] - 18s 103ms/step - loss: 7.4539e-04 - val_loss: 0.0034
# Epoch 11/30
# 176/176 [==============================] - 18s 104ms/step - loss: 7.0856e-04 - val_loss: 0.0015
# Epoch 12/30
# 176/176 [==============================] - 18s 104ms/step - loss: 6.7290e-04 - val_loss: 0.0018
# Epoch 13/30
# 176/176 [==============================] - 18s 105ms/step - loss: 6.9027e-04 - val_loss: 0.0020
# Epoch 14/30
# 176/176 [==============================] - 18s 102ms/step - loss: 6.7055e-04 - val_loss: 0.0017
# Epoch 15/30
# 176/176 [==============================] - 18s 104ms/step - loss: 7.3807e-04 - val_loss: 0.0012
# Epoch 16/30
# 176/176 [==============================] - 18s 105ms/step - loss: 6.3652e-04 - val_loss: 0.0011
# Epoch 17/30
# 176/176 [==============================] - 18s 103ms/step - loss: 6.3543e-04 - val_loss: 0.0022
# Epoch 18/30
# 176/176 [==============================] - 18s 104ms/step - loss: 5.7460e-04 - val_loss: 0.0013
# Epoch 19/30
# 176/176 [==============================] - 18s 104ms/step - loss: 6.1125e-04 - val_loss: 0.0014
# Epoch 20/30
# 176/176 [==============================] - 19s 107ms/step - loss: 5.2191e-04 - val_loss: 0.0011
# Epoch 21/30
# 176/176 [==============================] - 18s 103ms/step - loss: 5.1628e-04 - val_loss: 0.0014
# Epoch 22/30
# 176/176 [==============================] - 19s 107ms/step - loss: 4.7087e-04 - val_loss: 0.0011
# Epoch 23/30
# 176/176 [==============================] - 18s 105ms/step - loss: 4.3025e-04 - val_loss: 0.0010
# Epoch 24/30
# 176/176 [==============================] - 19s 105ms/step - loss: 4.3091e-04 - val_loss: 0.0010
# Epoch 25/30
# 176/176 [==============================] - 18s 104ms/step - loss: 4.4397e-04 - val_loss: 9.2750e-04
# Epoch 26/30
# 176/176 [==============================] - 19s 105ms/step - loss: 3.8128e-04 - val_loss: 0.0010
# Epoch 27/30
# 176/176 [==============================] - 19s 106ms/step - loss: 3.5230e-04 - val_loss: 9.4926e-04
# Epoch 28/30
# 176/176 [==============================] - 18s 105ms/step - loss: 3.4576e-04 - val_loss: 7.8221e-04
# Epoch 29/30
# 176/176 [==============================] - 18s 104ms/step - loss: 3.4999e-04 - val_loss: 7.9831e-04
# Epoch 30/30
# 176/176 [==============================] - 18s 103ms/step - loss: 3.0251e-04 - val_loss: 8.3051e-04

# %% [markdown]
# ### 5. Making predictions

# %%
y_pred = model.predict(X_test)

for i in range(10):
    print(y_pred[i], y_test[i])
# Out:
# 11/11 [==============================] - 1s 46ms/step
# [0.7597459] [0.76103027]
# [0.7523142] [0.73863386]
# [0.7360013] [0.7547593]
# [0.72739965] [0.69540877]
# [0.7053293] [0.69406486]
# [0.6877152] [0.72519604]
# [0.6789442] [0.62665177]
# [0.65767616] [0.68107507]
# [0.67053455] [0.6445688]
# [0.6637998] [0.6947369]

# %%
plt.plot(y_test, color = 'blue', label = 'Test')
plt.plot(y_pred, color = 'red', label = 'pred')
plt.legend()
plt.show()

# %% [markdown]
# ### 6. Calculating Error metrics

# %%
# removing last prediction, (nan values to calculate the right metrics)
y_test = y_test[:-1]
y_pred = y_pred[:-1]

# %%
def MAPE(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    MAPE = np.nanmean(np.abs((actual - pred) / actual)) * 100
    return MAPE

def MAE(actual, pred):
    MAE = mean_absolute_error(actual, pred)
    return MAE

def RMSE(actual, pred):
    RMSE = mean_squared_error(actual, pred, squared = False)
    return RMSE

# %%
MAPE(y_test, y_pred)
# Out:
# 4.534699006274404

# %%
MAE(y_test, y_pred)
# Out:
# 0.02392498401399993

# %%
RMSE(y_test, y_pred)
# Out:
# 0.029847761390716914

# %% [markdown]
# We can cleary see the improvement from the feature engineering made in the second version of the model, reducing every error metric observated.

# %% [markdown]
# ### Next Steps:
#     - test new hyperparametrs (Grid search, Random search, Hill climbing, Bayesian optimization)
#     - Run versions to predict diferent targets(target next diference, target next day up/down)
