# %% [markdown]
# ## 1. importing packages

# %%
import pandas as pd
import pandas_ta as ta
import numpy as np
import datetime as dt
import pandas_datareader as web
from tqdm import tqdm
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import matplotlib.ticker as ticker
import itertools

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV

import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate
from tensorflow.keras.callbacks import History, EarlyStopping
from tensorflow.keras import optimizers

import keras_tuner as kt
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## 2. overall configurations

# %%
# %matplotlib inline


tqdm.pandas()
sns.set(style='whitegrid',palette='muted')
rcParams['figure.figsize'] = 14, 10

# %% [markdown]
# ## 3. Getting the Data

# %%
import yfinance as yf
ticket = yf.Ticker('BOVA11.SA')
start = dt.datetime(2009, 1, 2) # First register data
end = dt.datetime(dt.datetime.now().year,dt.datetime.now().month,dt.datetime.now().day - 2)

bova11 = ticket.history(interval= '1d', start = start, end = end).reset_index()
bova11
bova11_copy = bova11.copy()

# %%
len(bova11)
# Out:
# 3487

# %% [markdown]
# ## 4. Pre-processing

# %% [markdown]
# Adjust the columns name and type

# %%
bova11.columns = bova11.columns.str.lower()

# %%
bova11.date = pd.to_datetime(bova11.date)

# %%
bova11.isna().sum()
# Out:
# date            0
# open            0
# high            0
# low             0
# close           0
# volume          0
# dividends       0
# stock splits    0
# dtype: int64

# %% [markdown]
# Removing rows with volume 0

# %%
bova11 = bova11.loc[(bova11.volume != 0)].reset_index()
bova11.drop(columns='index', axis = 1, inplace = True)
bova11
# Out:
#                           date        open        high         low  \
# 0    2009-01-02 00:00:00-02:00   38.279999   40.320000   37.939999
# 1    2009-01-05 00:00:00-02:00   40.200001   42.000000   39.700001
# 2    2009-01-06 00:00:00-02:00   42.060001   42.320000   41.549999
# 3    2009-01-07 00:00:00-02:00   41.750000   41.770000   40.450001
# 4    2009-01-08 00:00:00-02:00   40.150002   42.200001   40.150002
# ...                        ...         ...         ...         ...
# 3389 2023-01-13 00:00:00-03:00  106.940002  107.639999  106.690002
# 3390 2023-01-16 00:00:00-03:00  106.949997  106.949997  105.129997
# 3391 2023-01-17 00:00:00-03:00  106.239998  107.980003  106.220001
# 3392 2023-01-18 00:00:00-03:00  108.830002  109.599998  108.330002
# 3393 2023-01-19 00:00:00-03:00  107.699997  109.540001  107.610001
#
#            close   volume  dividends  stock splits
# 0      40.320000   119900          0             0
# 1      42.000000   341700          0             0
# 2      42.320000   178300          0             0
# 3      40.639999    73400          0             0
# 4      42.200001   195300          0             0
# ...          ...      ...        ...           ...
# 3389  107.349998  4742049          0             0
# 3390  105.470001  6905014          0             0
# 3391  107.800003  6647627          0             0
# 3392  108.330002  9405455          0             0
# 3393  109.110001  4378786          0             0
#
# [3394 rows x 8 columns]

# %% [markdown]
# Sorting the data by date

# %%
bova11 = bova11.sort_values(by='date').reset_index(drop=True)

# %% [markdown]
# Adding a column with the previous close value

# %%
bova11["prev_close"] = bova11.shift(1)["close"]

# %%
bova11.head()
# Out:
#                        date       open       high        low      close  \
# 0 2009-01-02 00:00:00-02:00  38.279999  40.320000  37.939999  40.320000
# 1 2009-01-05 00:00:00-02:00  40.200001  42.000000  39.700001  42.000000
# 2 2009-01-06 00:00:00-02:00  42.060001  42.320000  41.549999  42.320000
# 3 2009-01-07 00:00:00-02:00  41.750000  41.770000  40.450001  40.639999
# 4 2009-01-08 00:00:00-02:00  40.150002  42.200001  40.150002  42.200001
#
#    volume  dividends  stock splits  prev_close
# 0  119900          0             0         NaN
# 1  341700          0             0   40.320000
# 2  178300          0             0   42.000000
# 3   73400          0             0   42.320000
# 4  195300          0             0   40.639999

# %% [markdown]
# Adding the close difference between dates

# %%
bova11["close_change"]= bova11.progress_apply(
    lambda row: 0 if np.isnan(row.prev_close) else row.close - row.prev_close,
    axis = 1
)
# Out:
# 100%|██████████| 3394/3394 [00:00<00:00, 13859.99it/s]

# %%
bova11.head()
# Out:
#                        date       open       high        low      close  \
# 0 2009-01-02 00:00:00-02:00  38.279999  40.320000  37.939999  40.320000
# 1 2009-01-05 00:00:00-02:00  40.200001  42.000000  39.700001  42.000000
# 2 2009-01-06 00:00:00-02:00  42.060001  42.320000  41.549999  42.320000
# 3 2009-01-07 00:00:00-02:00  41.750000  41.770000  40.450001  40.639999
# 4 2009-01-08 00:00:00-02:00  40.150002  42.200001  40.150002  42.200001
#
#    volume  dividends  stock splits  prev_close  close_change
# 0  119900          0             0         NaN      0.000000
# 1  341700          0             0   40.320000      1.680000
# 2  178300          0             0   42.000000      0.320000
# 3   73400          0             0   42.320000     -1.680000
# 4  195300          0             0   40.639999      1.560001

# %% [markdown]
# Checking the dataseries over time

# %%
daily_closing = bova11[['date','close']]
daily_closing = daily_closing.set_index('date')
ax = daily_closing.plot()
plt.title('Valor de fechamento do BOVA11 ao longo dos anos')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R${x:,.2f}"))

# %% [markdown]
# #### Feature Engineering
# Add auxiliar columns that can improve our model, like moving averages,standard deviation, techinical indicators and others
# Let's add:
# - Moving_average for 3, 10, 30 and 60 days
# - Standard deviation for 7, 30 and 60 days
# - Bollinger limits for Upper and lowers 3, 30 and 60
# - Add RSI indicator

# %%
# Adding move Averages columns
bova11['ma_3d'] = bova11['close'].rolling(3, center = True, min_periods=1).mean()
bova11['ma_10d'] = bova11['close'].rolling(10, center = True,min_periods=1).mean()
bova11['ma_30d'] = bova11['close'].rolling(30, center=True, min_periods=1).mean()
bova11['ma_60d'] = bova11['close'].rolling(60, center = True, min_periods = 1).mean()

# %%
# Adding standard deviation columns
bova11['std_7'] = bova11['close'].rolling(7, center = True, min_periods = 1).std()
bova11['std_30'] = bova11['close'].rolling(30, center = True, min_periods = 1).std()
bova11['std_60'] = bova11['close'].rolling(60, center = True, min_periods = 1).std()

# %%
# Adding the bollinger bands
bova11['upper3'] = bova11['ma_3d'] + 2*bova11['close'].rolling(3, center = True, min_periods = 1).std()
bova11['lower3'] = bova11['ma_3d'] - 2*bova11['close'].rolling(3, center = True, min_periods = 1).std()

bova11['upper30'] = bova11['ma_30d'] + 2*bova11['std_30']
bova11['lower30'] = bova11['ma_30d'] - 2*bova11['std_30']

bova11['upper60'] = bova11['ma_60d'] + 2*bova11['std_60']
bova11['lower60'] = bova11['ma_60d'] - 2*bova11['std_60']

# %%
# Adding tecnical indicator RSI
bova11['RSI'] = ta.rsi(bova11['close'], length = 15)

# %%
moving_avg = bova11[['date','ma_30d']]
moving_avg = moving_avg.set_index('date')
ax = moving_avg.plot()
plt.title('Valor de fechamento do IBOVESPA ao longo dos anos')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R${x:,.2f}"))

# %% [markdown]
# Select the features and the predict columns

# %%
bova11.drop(['date', 'volume', 'dividends', 'stock splits', 'prev_close'],
            axis = 1,
           inplace = True)

# %%
bova11
# Out:
#             open        high         low       close  close_change  \
# 0      38.279999   40.320000   37.939999   40.320000      0.000000
# 1      40.200001   42.000000   39.700001   42.000000      1.680000
# 2      42.060001   42.320000   41.549999   42.320000      0.320000
# 3      41.750000   41.770000   40.450001   40.639999     -1.680000
# 4      40.150002   42.200001   40.150002   42.200001      1.560001
# ...          ...         ...         ...         ...           ...
# 3389  106.940002  107.639999  106.690002  107.349998     -0.910004
# 3390  106.949997  106.949997  105.129997  105.470001     -1.879997
# 3391  106.239998  107.980003  106.220001  107.800003      2.330002
# 3392  108.830002  109.599998  108.330002  108.330002      0.529999
# 3393  107.699997  109.540001  107.610001  109.110001      0.779999
#
#            ma_3d      ma_10d      ma_30d      ma_60d     std_7    std_30  \
# 0      41.160000   41.496000   40.072667   40.216334  0.987387  1.459904
# 1      41.546666   41.580000   39.948125   40.269033  0.941319  1.495795
# 2      41.653333   41.311429   39.892353   40.322813  0.866718  1.466439
# 3      41.720000   41.147500   39.842223   40.313031  1.063445  1.438465
# 4      41.613333   40.801111   39.897895   40.303530  1.118613  1.418844
# ...          ...         ...         ...         ...       ...       ...
# 3389  107.026667  107.345000  105.774000  104.783143  1.156308  2.345566
# 3390  106.873334  107.550001  105.871053  104.716177  1.253923  2.368223
# 3391  107.200002  107.825001  105.863889  104.618182  1.249128  2.436669
# 3392  108.413335  107.917144  105.905882  104.586563  1.364888  2.504938
# 3393  108.720001  107.720001  105.968750  104.517097  1.566937  2.573200
#
#         std_60      upper3      lower3     upper30     lower30     upper60  \
# 0     1.394817   43.535879   38.784121   42.992476   37.152858   43.005967
# 1     1.402411   43.695279   39.398054   42.939715   36.956536   43.073854
# 2     1.412751   43.437411   39.869255   42.825231   36.959475   43.148315
# 3     1.391637   43.594461   39.845539   42.719153   36.965292   43.096304
# 4     1.371508   43.311019   39.915647   42.735582   37.060208   43.046547
# ...        ...         ...         ...         ...         ...         ...
# 3389  2.732308  109.872319  104.181015  110.465132  101.082868  110.247759
# 3390  2.744089  109.345284  104.401385  110.607498  101.134608  110.204354
# 3391  2.725552  110.242962  104.157042  110.737227  100.990551  110.069286
# 3392  2.763007  109.731260  107.095410  110.915759  100.896006  110.112577
# 3393  2.780130  109.823086  107.616916  111.115151  100.822349  110.077356
#
#         lower60        RSI
# 0     37.426700        NaN
# 1     37.464211        NaN
# 2     37.497311        NaN
# 3     37.529757        NaN
# 4     37.560513        NaN
# ...         ...        ...
# 3389  99.318527  55.137312
# 3390  99.227999  50.240974
# 3391  99.167079  55.489642
# 3392  99.060548  56.605212
# 3393  98.956838  58.254979
#
# [3394 rows x 19 columns]

# %%
bova11['target'] = bova11.close - bova11.open
#bova11['targetClass'] = [1 if bova11.target[i] > 0 else 0 for i in range(len(bova11))]
bova11['targetNextClose'] = bova11['close'].shift(-1)

# %%
bova11
# Out:
#             open        high         low       close  close_change  \
# 0      38.279999   40.320000   37.939999   40.320000      0.000000
# 1      40.200001   42.000000   39.700001   42.000000      1.680000
# 2      42.060001   42.320000   41.549999   42.320000      0.320000
# 3      41.750000   41.770000   40.450001   40.639999     -1.680000
# 4      40.150002   42.200001   40.150002   42.200001      1.560001
# ...          ...         ...         ...         ...           ...
# 3389  106.940002  107.639999  106.690002  107.349998     -0.910004
# 3390  106.949997  106.949997  105.129997  105.470001     -1.879997
# 3391  106.239998  107.980003  106.220001  107.800003      2.330002
# 3392  108.830002  109.599998  108.330002  108.330002      0.529999
# 3393  107.699997  109.540001  107.610001  109.110001      0.779999
#
#            ma_3d      ma_10d      ma_30d      ma_60d     std_7  ...    std_60  \
# 0      41.160000   41.496000   40.072667   40.216334  0.987387  ...  1.394817
# 1      41.546666   41.580000   39.948125   40.269033  0.941319  ...  1.402411
# 2      41.653333   41.311429   39.892353   40.322813  0.866718  ...  1.412751
# 3      41.720000   41.147500   39.842223   40.313031  1.063445  ...  1.391637
# 4      41.613333   40.801111   39.897895   40.303530  1.118613  ...  1.371508
# ...          ...         ...         ...         ...       ...  ...       ...
# 3389  107.026667  107.345000  105.774000  104.783143  1.156308  ...  2.732308
# 3390  106.873334  107.550001  105.871053  104.716177  1.253923  ...  2.744089
# 3391  107.200002  107.825001  105.863889  104.618182  1.249128  ...  2.725552
# 3392  108.413335  107.917144  105.905882  104.586563  1.364888  ...  2.763007
# 3393  108.720001  107.720001  105.968750  104.517097  1.566937  ...  2.780130
#
#           upper3      lower3     upper30     lower30     upper60    lower60  \
# 0      43.535879   38.784121   42.992476   37.152858   43.005967  37.426700
# 1      43.695279   39.398054   42.939715   36.956536   43.073854  37.464211
# 2      43.437411   39.869255   42.825231   36.959475   43.148315  37.497311
# 3      43.594461   39.845539   42.719153   36.965292   43.096304  37.529757
# 4      43.311019   39.915647   42.735582   37.060208   43.046547  37.560513
# ...          ...         ...         ...         ...         ...        ...
# 3389  109.872319  104.181015  110.465132  101.082868  110.247759  99.318527
# 3390  109.345284  104.401385  110.607498  101.134608  110.204354  99.227999
# 3391  110.242962  104.157042  110.737227  100.990551  110.069286  99.167079
# 3392  109.731260  107.095410  110.915759  100.896006  110.112577  99.060548
# 3393  109.823086  107.616916  111.115151  100.822349  110.077356  98.956838
#
#             RSI    target  targetNextClose
# 0           NaN  2.040001        42.000000
# 1           NaN  1.799999        42.320000
# 2           NaN  0.259998        40.639999
# 3           NaN -1.110001        42.200001
# 4           NaN  2.049999        42.000000
# ...         ...       ...              ...
# 3389  55.137312  0.409996       105.470001
# 3390  50.240974 -1.479996       107.800003
# 3391  55.489642  1.560005       108.330002
# 3392  56.605212 -0.500000       109.110001
# 3393  58.254979  1.410004              NaN
#
# [3394 rows x 21 columns]

# %%
bova11.dropna(inplace = True)

# %%
scaler = MinMaxScaler(feature_range = (-1, 1))
bova11_scaled = scaler.fit_transform(bova11)
print(bova11_scaled)
# Out:
# [[-0.41052802 -0.95937954 -0.97594966 ... -0.34158244 -0.812735
#   -0.94288915]
#  [-0.39380423 -0.93549828 -0.95100022 ... -0.1145866  -0.81635782
#   -0.94311308]
#  [-0.38663696 -0.9468809  -0.94178467 ... -0.11645738 -0.82917641
#   -0.90033593]
#  ...
#  [ 0.7034323   0.56991398  0.55990106 ...  0.05444169 -0.8837953
#    0.59798439]
#  [ 0.69212389  0.59290263  0.58440103 ...  0.21208654 -0.79908022
#    0.60985446]
#  [ 0.73337584  0.6290592   0.63182744 ...  0.2455929  -0.85648596
#    0.62732364]]

# %% [markdown]
# Select the features and prediction target columns

# %%
backcandles = 100
X = []
for j in range(19): # range is the number of feature columns you will use
    X.append([])
    for i in range(backcandles, bova11_scaled.shape[0]):
        X[j].append(bova11_scaled[i-backcandles:i, j])

#move axis from 0 to position 2
X = np.moveaxis(X, [0], [2])

X, yi = np.array(X), np.array(bova11_scaled[backcandles:, -1]) # Chosing the last column as the pred. target
y = np.reshape(yi, (len(yi), 1))

X.shape, y.shape
# Out:
# ((3278, 100, 19), (3278, 1))

# %% [markdown]
# Split the train and test data

# %%
splitlimit = int(len(X) * 0.9)
X_train, X_test = X[:splitlimit], X[splitlimit+1:]
y_train, y_test = y[:splitlimit], y[splitlimit+1:]

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (2950, 100, 19) (327, 100, 19) (2950, 1) (327, 1)

# %% [markdown]
# ### 4. Creating the model

# %%
def create_lstm_model(backcandles, num_features, dropout_prob):
    model = Sequential()
    model.add(LSTM(64, input_shape = (backcandles, num_features)))
    model.add(Dropout(dropout_prob))
    model.add(Dense(1))
    adam = optimizers.Adam()
    model.compile(optimizer=adam, loss = 'mse')
    return model

# %%
model = create_lstm_model(100, 19, 0.1)
model.fit(x = X_train, y = y_train, batch_size = 16, epochs = 10, shuffle = True, validation_split = 0.1)
# Out:
# Epoch 1/10
# 166/166 [==============================] - 10s 41ms/step - loss: 0.0118 - val_loss: 0.0017
# Epoch 2/10
# 166/166 [==============================] - 7s 39ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 3/10
# 166/166 [==============================] - 6s 39ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 4/10
# 166/166 [==============================] - 6s 38ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 5/10
# 166/166 [==============================] - 7s 39ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 6/10
# 166/166 [==============================] - 6s 35ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 7/10
# 166/166 [==============================] - 6s 37ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 8/10
# 166/166 [==============================] - 6s 37ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 9/10
# 166/166 [==============================] - 6s 37ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 10/10
# 166/166 [==============================] - 7s 41ms/step - loss: 0.0015 - val_loss: 0.0013

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0017

# %% [markdown]
# ### 5. Making predictions

# %%
y_pred = model.predict(X_test)

for i in range(10):
    print(y_pred[i], y_test[i])
# Out:
# 11/11 [==============================] - 1s 28ms/step
# [0.61223376] [0.57625984]
# [0.5792737] [0.56864497]
# [0.58522713] [0.6134378]
# [0.58395445] [0.56170213]
# [0.6034976] [0.5603584]
# [0.57968354] [0.5659575]
# [0.57629955] [0.56707722]
# [0.57445633] [0.61119819]
# [0.5756953] [0.5968645]
# [0.59861004] [0.63023511]

# %%
y_pred.shape
# Out:
# (327, 1)

# %%
plt.plot(y_test, color = 'blue', label = 'Test')
plt.plot(y_pred, color = 'red', label = 'pred')
plt.legend()
plt.show()

# %% [markdown]
# ### 6. Calculating Error metrics

# %%
def MAPE(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    MAPE = np.nanmean(np.abs((actual - pred) / actual)) * 100
    return MAPE

def MAE(actual, pred):
    MAE = mean_absolute_error(actual, pred)
    return MAE

def RMSE(actual, pred):
    RMSE = mean_squared_error(actual, pred, squared = False)
    return RMSE

# %%
MAPE(y_test, y_pred)
# Out:
# 6.612625682130095

# %%
MAE(y_test, y_pred)
# Out:
# 0.033633402464968314

# %%
RMSE(y_test, y_pred)
# Out:
# 0.04111076779552466

# %%
backcandles = 50
X = []
for j in range(19): # range is the number of feature columns you will use
    X.append([])
    for i in range(backcandles, bova11_scaled.shape[0]):
        X[j].append(bova11_scaled[i-backcandles:i, j])

#move axis from 0 to position 2
X = np.moveaxis(X, [0], [2])

X, yi = np.array(X), np.array(bova11_scaled[backcandles:, -1]) # Chosing the last column as the pred. target
y = np.reshape(yi, (len(yi), 1))
    
splitlimit = int(len(X) * 0.9)
x_train, x_test = X[:splitlimit], X[splitlimit+1:]
y_train, y_test = y[:splitlimit], y[splitlimit+1:]

# %% [markdown]
# ### 7. Tuning the hyperparameters

# %%
def LSTM_hyperparameter_tuning(config):
    first_add_layer, second_add_layer, third_add_layer, n_neurons, n_batch_size, dropout, pass_days = config
    combinations = list(itertools.product(first_add_layer, second_add_layer, third_add_layer,
                                         n_neurons, n_batch_size, dropout, pass_days))
    print(combinations)
    print('\n')
    
    hist = []
    
    for i in range(0, len(combinations)):
        
        print(f'{i+1}th combination: \n')
        print('-'* 100)
        
        first_add_layer, second_add_layer, third_add_layer, n_neurons, n_batch_size, dropout, pass_days = combinations[i]
        
        print(combinations[i])
        
        backcandles = pass_days
        X = []
        for j in range(19): # range is the number of feature columns you will use
            X.append([])
            for k in range(backcandles, bova11_scaled.shape[0]):
                X[j].append(bova11_scaled[k-backcandles:k, j])

        #move axis from 0 to position 2
        X = np.moveaxis(X, [0], [2])

        X, yi = np.array(X), np.array(bova11_scaled[backcandles:, -1]) # Chosing the last column as the pred. target
        y = np.reshape(yi, (len(yi), 1))

        splitlimit = int(len(X) * 0.9)
        x_train, x_test = X[:splitlimit], X[splitlimit+1:]
        y_train, y_test = y[:splitlimit], y[splitlimit+1:]
        
        model = Sequential()
        model.add(LSTM(units = n_neurons, return_sequences = True,
                 input_shape = (x_train.shape[1], x_train.shape[2])))
        model.add(Dropout(dropout))
        
        if first_add_layer:
            model.add(LSTM(units = n_neurons, return_sequences = True))
            model.add(Dropout(dropout))
        
        if second_add_layer:
            model.add(LSTM(units = n_neurons, return_sequences = True))
            model.add(Dropout(dropout))
        
        if third_add_layer:
            model.add(LSTM(units = n_neurons, return_sequences = True))
            model.add(Dropout(dropout))
        
        model.add(LSTM(units = n_neurons, return_sequences = False))
        model.add(Dropout(dropout))
        model.add(Dense(units = 1, activation = 'linear'))
        model.compile(optimizer = 'adam', 
                      loss = 'mse', 
                      metrics = [tf.keras.metrics.RootMeanSquaredError()])
        
        es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 7)
        
        file_path = 'best_model.h5'
        
        mc = ModelCheckpoint(file_path, monitor = 'val_loss', mode = 'min', verbose = 1, save_best_only = True)
        
        model.fit(x_train, y_train, 
                  validation_split = 0.1, 
                  epochs = 50, 
                  batch_size = n_batch_size,
                  callbacks = [es, mc], 
                  verbose = 0,
                  shuffle = True)
        train_accuracy = model.evaluate(x_train, y_train, verbose = 0)
        test_accuracy = model.evaluate(x_test, y_test, verbose = 0)
        
        hist.append(list((first_add_layer, second_add_layer, third_add_layer, n_neurons, n_batch_size, dropout,pass_days, train_accuracy, test_accuracy)))
        
        print(f'{str(i)}-th combination = {combinations[i]} \n train accucary: {train_accuracy} and test accuracy: {test_accuracy}')
        print('-' * 100)
        print('-'* 100)
        
    return hist

# %%
config = [[False], [False], [False], [256, 128, 64], [16,32],[0.2], [50,100]]

hist = LSTM_hyperparameter_tuning(config)
# Out:
# [(False, False, False, 256, 16, 0.2, 50), (False, False, False, 256, 16, 0.2, 100), (False, False, False, 256, 32, 0.2, 50), (False, False, False, 256, 32, 0.2, 100), (False, False, False, 128, 16, 0.2, 50), (False, False, False, 128, 16, 0.2, 100), (False, False, False, 128, 32, 0.2, 50), (False, False, False, 128, 32, 0.2, 100), (False, False, False, 64, 16, 0.2, 50), (False, False, False, 64, 16, 0.2, 100), (False, False, False, 64, 32, 0.2, 50), (False, False, False, 64, 32, 0.2, 100)]
#
#
# 1th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 256, 16, 0.2, 50)
#
# Epoch 1: val_loss improved from inf to 0.00455, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.00455
#
# Epoch 3: val_loss improved from 0.00455 to 0.00172, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.00172
#
# Epoch 5: val_loss did not improve from 0.00172
#
# Epoch 6: val_loss improved from 0.00172 to 0.00153, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.00153
#
# Epoch 8: val_loss did not improve from 0.00153
#
# Epoch 9: val_loss improved from 0.00153 to 0.00152, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.00152
#
# Epoch 11: val_loss did not improve from 0.00152
#
# Epoch 12: val_loss did not improve from 0.00152
#
# Epoch 13: val_loss did not improve from 0.00152
#
# Epoch 14: val_loss did not improve from 0.00152
#
# Epoch 15: val_loss did not improve from 0.00152
#
# Epoch 16: val_loss did not improve from 0.00152
# Epoch 16: early stopping
# 0-th combination = (False, False, False, 256, 16, 0.2, 50)
#  train accucary: [0.0010594248306006193, 0.03254880756139755] and test accuracy: [0.001946031698025763, 0.044113848358392715]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 2th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 256, 16, 0.2, 100)
#
# Epoch 1: val_loss improved from inf to 0.00251, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.00251 to 0.00155, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.00155
#
# Epoch 4: val_loss did not improve from 0.00155
#
# Epoch 5: val_loss did not improve from 0.00155
#
# Epoch 6: val_loss improved from 0.00155 to 0.00140, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.00140
#
# Epoch 8: val_loss improved from 0.00140 to 0.00132, saving model to best_model.h5
#
# Epoch 9: val_loss did not improve from 0.00132
#
# Epoch 10: val_loss did not improve from 0.00132
#
# Epoch 11: val_loss did not improve from 0.00132
#
# Epoch 12: val_loss improved from 0.00132 to 0.00122, saving model to best_model.h5
#
# Epoch 13: val_loss did not improve from 0.00122
#
# Epoch 14: val_loss did not improve from 0.00122
#
# Epoch 15: val_loss did not improve from 0.00122
#
# Epoch 16: val_loss did not improve from 0.00122
#
# Epoch 17: val_loss did not improve from 0.00122
#
# Epoch 18: val_loss did not improve from 0.00122
#
# Epoch 19: val_loss did not improve from 0.00122
# Epoch 19: early stopping
# 1-th combination = (False, False, False, 256, 16, 0.2, 100)
#  train accucary: [0.0019061012426391244, 0.043658919632434845] and test accuracy: [0.006426885724067688, 0.08016785979270935]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 3th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 256, 32, 0.2, 50)
#
# Epoch 1: val_loss improved from inf to 0.00509, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.00509 to 0.00285, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.00285 to 0.00183, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.00183
#
# Epoch 5: val_loss did not improve from 0.00183
#
# Epoch 6: val_loss did not improve from 0.00183
#
# Epoch 7: val_loss did not improve from 0.00183
#
# Epoch 8: val_loss did not improve from 0.00183
#
# Epoch 9: val_loss improved from 0.00183 to 0.00152, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.00152
#
# Epoch 11: val_loss improved from 0.00152 to 0.00131, saving model to best_model.h5
#
# Epoch 12: val_loss did not improve from 0.00131
#
# Epoch 13: val_loss did not improve from 0.00131
#
# Epoch 14: val_loss did not improve from 0.00131
#
# Epoch 15: val_loss did not improve from 0.00131
#
# Epoch 16: val_loss improved from 0.00131 to 0.00127, saving model to best_model.h5
#
# Epoch 17: val_loss did not improve from 0.00127
#
# Epoch 18: val_loss improved from 0.00127 to 0.00124, saving model to best_model.h5
#
# Epoch 19: val_loss did not improve from 0.00124
#
# Epoch 20: val_loss did not improve from 0.00124
#
# Epoch 21: val_loss did not improve from 0.00124
#
# Epoch 22: val_loss did not improve from 0.00124
#
# Epoch 23: val_loss improved from 0.00124 to 0.00113, saving model to best_model.h5
#
# Epoch 24: val_loss did not improve from 0.00113
#
# Epoch 25: val_loss did not improve from 0.00113
#
# Epoch 26: val_loss did not improve from 0.00113
#
# Epoch 27: val_loss did not improve from 0.00113
#
# Epoch 28: val_loss did not improve from 0.00113
#
# Epoch 29: val_loss did not improve from 0.00113
#
# Epoch 30: val_loss did not improve from 0.00113
# Epoch 30: early stopping
# 2-th combination = (False, False, False, 256, 32, 0.2, 50)
#  train accucary: [0.0011282999766990542, 0.033590175211429596] and test accuracy: [0.0028719338588416576, 0.053590428084135056]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 4th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 256, 32, 0.2, 100)
#
# Epoch 1: val_loss improved from inf to 0.00363, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.00363
#
# Epoch 3: val_loss improved from 0.00363 to 0.00254, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.00254
#
# Epoch 5: val_loss improved from 0.00254 to 0.00195, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.00195 to 0.00177, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.00177 to 0.00155, saving model to best_model.h5
#
# Epoch 8: val_loss improved from 0.00155 to 0.00151, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 0.00151 to 0.00134, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.00134
#
# Epoch 11: val_loss did not improve from 0.00134
#
# Epoch 12: val_loss did not improve from 0.00134
#
# Epoch 13: val_loss did not improve from 0.00134
#
# Epoch 14: val_loss did not improve from 0.00134
#
# Epoch 15: val_loss improved from 0.00134 to 0.00134, saving model to best_model.h5
#
# Epoch 16: val_loss improved from 0.00134 to 0.00129, saving model to best_model.h5
#
# Epoch 17: val_loss did not improve from 0.00129
#
# Epoch 18: val_loss did not improve from 0.00129
#
# Epoch 19: val_loss did not improve from 0.00129
#
# Epoch 20: val_loss did not improve from 0.00129
#
# Epoch 21: val_loss did not improve from 0.00129
#
# Epoch 22: val_loss improved from 0.00129 to 0.00122, saving model to best_model.h5
#
# Epoch 23: val_loss did not improve from 0.00122
#
# Epoch 24: val_loss did not improve from 0.00122
#
# Epoch 25: val_loss did not improve from 0.00122
#
# Epoch 26: val_loss did not improve from 0.00122
#
# Epoch 27: val_loss did not improve from 0.00122
#
# Epoch 28: val_loss did not improve from 0.00122
#
# Epoch 29: val_loss improved from 0.00122 to 0.00109, saving model to best_model.h5
#
# Epoch 30: val_loss did not improve from 0.00109
#
# Epoch 31: val_loss did not improve from 0.00109
#
# Epoch 32: val_loss did not improve from 0.00109
#
# Epoch 33: val_loss did not improve from 0.00109
#
# Epoch 34: val_loss did not improve from 0.00109
#
# Epoch 35: val_loss did not improve from 0.00109
# Epoch 36: val_loss did not improve from 0.00109
# Epoch 36: early stopping
# 3-th combination = (False, False, False, 256, 32, 0.2, 100)
#  train accucary: [0.0006059178267605603, 0.024615397676825523] and test accuracy: [0.0013455254957079887, 0.0366814061999321]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 5th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 128, 16, 0.2, 50)
#
# Epoch 1: val_loss improved from inf to 0.01285, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.01285 to 0.00229, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.00229 to 0.00169, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.00169 to 0.00146, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.00146
#
# Epoch 6: val_loss did not improve from 0.00146
#
# Epoch 7: val_loss improved from 0.00146 to 0.00130, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.00130
#
# Epoch 9: val_loss did not improve from 0.00130
#
# Epoch 10: val_loss did not improve from 0.00130
#
# Epoch 11: val_loss did not improve from 0.00130
#
# Epoch 12: val_loss did not improve from 0.00130
#
# Epoch 13: val_loss did not improve from 0.00130
#
# Epoch 14: val_loss did not improve from 0.00130
# Epoch 14: early stopping
# 4-th combination = (False, False, False, 128, 16, 0.2, 50)
#  train accucary: [0.0008209468214772642, 0.028652168810367584] and test accuracy: [0.001849859720095992, 0.04300999641418457]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 6th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 128, 16, 0.2, 100)
#
# Epoch 1: val_loss improved from inf to 0.00704, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.00704 to 0.00183, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.00183
#
# Epoch 4: val_loss improved from 0.00183 to 0.00178, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.00178
#
# Epoch 6: val_loss did not improve from 0.00178
#
# Epoch 7: val_loss improved from 0.00178 to 0.00144, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.00144
#
# Epoch 9: val_loss improved from 0.00144 to 0.00142, saving model to best_model.h5
#
# Epoch 10: val_loss improved from 0.00142 to 0.00137, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 0.00137
#
# Epoch 12: val_loss did not improve from 0.00137
#
# Epoch 13: val_loss improved from 0.00137 to 0.00130, saving model to best_model.h5
#
# Epoch 14: val_loss did not improve from 0.00130
#
# Epoch 15: val_loss did not improve from 0.00130
#
# Epoch 16: val_loss did not improve from 0.00130
#
# Epoch 17: val_loss did not improve from 0.00130
#
# Epoch 18: val_loss did not improve from 0.00130
#
# Epoch 19: val_loss did not improve from 0.00130
#
# Epoch 20: val_loss improved from 0.00130 to 0.00120, saving model to best_model.h5
#
# Epoch 21: val_loss did not improve from 0.00120
#
# Epoch 22: val_loss did not improve from 0.00120
#
# Epoch 23: val_loss did not improve from 0.00120
#
# Epoch 24: val_loss did not improve from 0.00120
#
# Epoch 25: val_loss did not improve from 0.00120
#
# Epoch 26: val_loss did not improve from 0.00120
#
# Epoch 27: val_loss did not improve from 0.00120
# Epoch 27: early stopping
# 5-th combination = (False, False, False, 128, 16, 0.2, 100)
#  train accucary: [0.002581238280981779, 0.05080588907003403] and test accuracy: [0.007101455703377724, 0.08427013456821442]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 7th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 128, 32, 0.2, 50)
#
# Epoch 1: val_loss improved from inf to 0.00317, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.00317
#
# Epoch 3: val_loss improved from 0.00317 to 0.00286, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.00286 to 0.00184, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.00184
#
# Epoch 6: val_loss did not improve from 0.00184
#
# Epoch 7: val_loss did not improve from 0.00184
#
# Epoch 8: val_loss improved from 0.00184 to 0.00159, saving model to best_model.h5
#
# Epoch 9: val_loss did not improve from 0.00159
#
# Epoch 10: val_loss improved from 0.00159 to 0.00154, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 0.00154
#
# Epoch 12: val_loss improved from 0.00154 to 0.00150, saving model to best_model.h5
#
# Epoch 13: val_loss did not improve from 0.00150
#
# Epoch 14: val_loss improved from 0.00150 to 0.00145, saving model to best_model.h5
#
# Epoch 15: val_loss improved from 0.00145 to 0.00142, saving model to best_model.h5
#
# Epoch 16: val_loss did not improve from 0.00142
#
# Epoch 17: val_loss improved from 0.00142 to 0.00137, saving model to best_model.h5
#
# Epoch 18: val_loss did not improve from 0.00137
#
# Epoch 19: val_loss did not improve from 0.00137
#
# Epoch 20: val_loss did not improve from 0.00137
#
# Epoch 21: val_loss did not improve from 0.00137
#
# Epoch 22: val_loss did not improve from 0.00137
#
# Epoch 23: val_loss improved from 0.00137 to 0.00130, saving model to best_model.h5
#
# Epoch 24: val_loss did not improve from 0.00130
#
# Epoch 25: val_loss did not improve from 0.00130
#
# Epoch 26: val_loss did not improve from 0.00130
#
# Epoch 27: val_loss did not improve from 0.00130
#
# Epoch 28: val_loss did not improve from 0.00130
#
# Epoch 29: val_loss did not improve from 0.00130
#
# Epoch 30: val_loss did not improve from 0.00130
# Epoch 30: early stopping
# 6-th combination = (False, False, False, 128, 32, 0.2, 50)
#  train accucary: [0.000704015139490366, 0.026533283293247223] and test accuracy: [0.0017592698568478227, 0.04194365069270134]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 8th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 128, 32, 0.2, 100)
#
# Epoch 1: val_loss improved from inf to 0.00354, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.00354
#
# Epoch 3: val_loss improved from 0.00354 to 0.00267, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.00267 to 0.00203, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 0.00203 to 0.00162, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.00162
#
# Epoch 7: val_loss improved from 0.00162 to 0.00152, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.00152
#
# Epoch 9: val_loss did not improve from 0.00152
#
# Epoch 10: val_loss did not improve from 0.00152
#
# Epoch 11: val_loss did not improve from 0.00152
#
# Epoch 12: val_loss improved from 0.00152 to 0.00145, saving model to best_model.h5
#
# Epoch 13: val_loss improved from 0.00145 to 0.00135, saving model to best_model.h5
#
# Epoch 14: val_loss did not improve from 0.00135
#
# Epoch 15: val_loss did not improve from 0.00135
#
# Epoch 16: val_loss did not improve from 0.00135
#
# Epoch 17: val_loss did not improve from 0.00135
#
# Epoch 18: val_loss did not improve from 0.00135
#
# Epoch 19: val_loss did not improve from 0.00135
#
# Epoch 20: val_loss did not improve from 0.00135
# Epoch 20: early stopping
# 7-th combination = (False, False, False, 128, 32, 0.2, 100)
#  train accucary: [0.0008662798209115863, 0.02943263202905655] and test accuracy: [0.002385309198871255, 0.04883962869644165]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 9th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 64, 16, 0.2, 50)
# Epoch 1: val_loss improved from inf to 0.00501, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.00501
#
# Epoch 3: val_loss improved from 0.00501 to 0.00264, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.00264 to 0.00172, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.00172
#
# Epoch 6: val_loss did not improve from 0.00172
#
# Epoch 7: val_loss did not improve from 0.00172
#
# Epoch 8: val_loss did not improve from 0.00172
#
# Epoch 9: val_loss did not improve from 0.00172
#
# Epoch 10: val_loss improved from 0.00172 to 0.00156, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 0.00156
#
# Epoch 12: val_loss did not improve from 0.00156
#
# Epoch 13: val_loss did not improve from 0.00156
#
# Epoch 14: val_loss did not improve from 0.00156
#
# Epoch 15: val_loss did not improve from 0.00156
#
# Epoch 16: val_loss did not improve from 0.00156
#
# Epoch 17: val_loss did not improve from 0.00156
# Epoch 17: early stopping
# 8-th combination = (False, False, False, 64, 16, 0.2, 50)
#  train accucary: [0.0008669572998769581, 0.029444139450788498] and test accuracy: [0.0020277511794120073, 0.04503055661916733]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 10th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 64, 16, 0.2, 100)
#
# Epoch 1: val_loss improved from inf to 0.00648, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.00648 to 0.00258, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.00258
#
# Epoch 4: val_loss did not improve from 0.00258
#
# Epoch 5: val_loss did not improve from 0.00258
#
# Epoch 6: val_loss improved from 0.00258 to 0.00234, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.00234 to 0.00213, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.00213
#
# Epoch 9: val_loss did not improve from 0.00213
#
# Epoch 10: val_loss did not improve from 0.00213
#
# Epoch 11: val_loss improved from 0.00213 to 0.00161, saving model to best_model.h5
#
# Epoch 12: val_loss did not improve from 0.00161
#
# Epoch 13: val_loss did not improve from 0.00161
#
# Epoch 14: val_loss did not improve from 0.00161
#
# Epoch 15: val_loss did not improve from 0.00161
#
# Epoch 16: val_loss did not improve from 0.00161
#
# Epoch 17: val_loss did not improve from 0.00161
#
# Epoch 18: val_loss improved from 0.00161 to 0.00161, saving model to best_model.h5
#
# Epoch 19: val_loss did not improve from 0.00161
#
# Epoch 20: val_loss did not improve from 0.00161
#
# Epoch 21: val_loss did not improve from 0.00161
#
# Epoch 22: val_loss improved from 0.00161 to 0.00144, saving model to best_model.h5
#
# Epoch 23: val_loss did not improve from 0.00144
#
# Epoch 24: val_loss did not improve from 0.00144
#
# Epoch 25: val_loss did not improve from 0.00144
#
# Epoch 26: val_loss did not improve from 0.00144
#
# Epoch 27: val_loss did not improve from 0.00144
#
# Epoch 28: val_loss did not improve from 0.00144
#
# Epoch 29: val_loss did not improve from 0.00144
# Epoch 29: early stopping
# 9-th combination = (False, False, False, 64, 16, 0.2, 100)
#  train accucary: [0.0007248580805025995, 0.02692318893969059] and test accuracy: [0.0016654124483466148, 0.04080946370959282]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 11th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 64, 32, 0.2, 50)
#
# Epoch 1: val_loss improved from inf to 0.00758, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.00758 to 0.00464, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.00464 to 0.00224, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.00224
#
# Epoch 5: val_loss improved from 0.00224 to 0.00180, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.00180
#
# Epoch 7: val_loss did not improve from 0.00180
#
# Epoch 8: val_loss did not improve from 0.00180
#
# Epoch 9: val_loss did not improve from 0.00180
#
# Epoch 10: val_loss did not improve from 0.00180
#
# Epoch 11: val_loss did not improve from 0.00180
#
# Epoch 12: val_loss did not improve from 0.00180
# Epoch 12: early stopping
# 10-th combination = (False, False, False, 64, 32, 0.2, 50)
#  train accucary: [0.0010902717476710677, 0.03301926329731941] and test accuracy: [0.0022059420589357615, 0.046967457979917526]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 12th combination:
#
# ----------------------------------------------------------------------------------------------------
# (False, False, False, 64, 32, 0.2, 100)
#
# Epoch 1: val_loss improved from inf to 0.00774, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.00774 to 0.00344, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.00344 to 0.00241, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.00241
#
# Epoch 5: val_loss did not improve from 0.00241
#
# Epoch 6: val_loss did not improve from 0.00241
#
# Epoch 7: val_loss improved from 0.00241 to 0.00226, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.00226
#
# Epoch 9: val_loss did not improve from 0.00226
#
# Epoch 10: val_loss did not improve from 0.00226
#
# Epoch 11: val_loss improved from 0.00226 to 0.00174, saving model to best_model.h5
#
# Epoch 12: val_loss did not improve from 0.00174
#
# Epoch 13: val_loss did not improve from 0.00174
#
# Epoch 14: val_loss did not improve from 0.00174
#
# Epoch 15: val_loss did not improve from 0.00174
#
# Epoch 16: val_loss improved from 0.00174 to 0.00168, saving model to best_model.h5
#
# Epoch 17: val_loss did not improve from 0.00168
#
# Epoch 18: val_loss did not improve from 0.00168
#
# Epoch 19: val_loss improved from 0.00168 to 0.00164, saving model to best_model.h5
#
# Epoch 20: val_loss did not improve from 0.00164
#
# Epoch 21: val_loss improved from 0.00164 to 0.00151, saving model to best_model.h5
#
# Epoch 22: val_loss did not improve from 0.00151
#
# Epoch 23: val_loss did not improve from 0.00151
#
# Epoch 24: val_loss did not improve from 0.00151
#
# Epoch 25: val_loss did not improve from 0.00151
#
# Epoch 26: val_loss improved from 0.00151 to 0.00140, saving model to best_model.h5
#
# Epoch 27: val_loss did not improve from 0.00140
#
# Epoch 28: val_loss did not improve from 0.00140
#
# Epoch 29: val_loss did not improve from 0.00140
#
# Epoch 30: val_loss improved from 0.00140 to 0.00135, saving model to best_model.h5
#
# Epoch 31: val_loss did not improve from 0.00135
#
# Epoch 32: val_loss did not improve from 0.00135
#
# Epoch 33: val_loss did not improve from 0.00135
#
# Epoch 34: val_loss did not improve from 0.00135
#
# Epoch 35: val_loss did not improve from 0.00135
#
# Epoch 36: val_loss did not improve from 0.00135
#
# Epoch 37: val_loss did not improve from 0.00135
# Epoch 37: early stopping
# 11-th combination = (False, False, False, 64, 32, 0.2, 100)
#  train accucary: [0.0009149021352641284, 0.03024734929203987] and test accuracy: [0.0017912030452862382, 0.04232260584831238]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Choosing the Best Model

# %%
x_train.shape
# Out:
# (2995, 50, 19)

# %%
y_train.shape
# Out:
# (2995, 1)

# %%
y_train.shape
# Out:
# (2995, 1)

# %%
hist = pd.DataFrame(hist)
hist = hist.sort_values(by= [7], ascending = True)
hist
# Out:
#         0      1      2    3   4    5    6  \
# 3   False  False  False  256  32  0.2  100
# 6   False  False  False  128  32  0.2   50
# 9   False  False  False   64  16  0.2  100
# 4   False  False  False  128  16  0.2   50
# 7   False  False  False  128  32  0.2  100
# 8   False  False  False   64  16  0.2   50
# 11  False  False  False   64  32  0.2  100
# 0   False  False  False  256  16  0.2   50
# 10  False  False  False   64  32  0.2   50
# 2   False  False  False  256  32  0.2   50
# 1   False  False  False  256  16  0.2  100
# 5   False  False  False  128  16  0.2  100
#
#                                                 7  \
# 3   [0.0006059178267605603, 0.024615397676825523]
# 6    [0.000704015139490366, 0.026533283293247223]
# 9    [0.0007248580805025995, 0.02692318893969059]
# 4   [0.0008209468214772642, 0.028652168810367584]
# 7    [0.0008662798209115863, 0.02943263202905655]
# 8   [0.0008669572998769581, 0.029444139450788498]
# 11   [0.0009149021352641284, 0.03024734929203987]
# 0    [0.0010594248306006193, 0.03254880756139755]
# 10   [0.0010902717476710677, 0.03301926329731941]
# 2   [0.0011282999766990542, 0.033590175211429596]
# 1   [0.0019061012426391244, 0.043658919632434845]
# 5     [0.002581238280981779, 0.05080588907003403]
#
#                                                 8
# 3     [0.0013455254957079887, 0.0366814061999321]
# 6    [0.0017592698568478227, 0.04194365069270134]
# 9    [0.0016654124483466148, 0.04080946370959282]
# 4     [0.001849859720095992, 0.04300999641418457]
# 7     [0.002385309198871255, 0.04883962869644165]
# 8    [0.0020277511794120073, 0.04503055661916733]
# 11   [0.0017912030452862382, 0.04232260584831238]
# 0    [0.001946031698025763, 0.044113848358392715]
# 10  [0.0022059420589357615, 0.046967457979917526]
# 2   [0.0028719338588416576, 0.053590428084135056]
# 1     [0.006426885724067688, 0.08016785979270935]
# 5     [0.007101455703377724, 0.08427013456821442]

# %%
print(f'Best Combination: \n first_additional_layer = {hist.iloc[0, 0]}\n second_additional_layer = {hist.iloc[0, 1]}\n third_additional_layer = {hist.iloc[0, 2]}\n n_neurons = {hist.iloc[0, 3]}\n n_batch_size = {hist.iloc[0, 4]}\n dropout = {hist.iloc[0, 5]}\n pass_days = {hist.iloc[0,6]}')

print(f'Results Before Tunning:\n Test Set RMSE: {np.round(results, 4)}\n')
print(f'Results After Tunning:\n Test Set RMSE: {np.round(hist.iloc[0, -2], 4)[1]}\n')
print(f'{np.round((results - hist.iloc[0, -2][1])*100/np.round(results, 4))}% Improvement')
# Out:
# Best Combination:
#  first_additional_layer = False
#  second_additional_layer = False
#  third_additional_layer = False
#  n_neurons = 256
#  n_batch_size = 32
#  dropout = 0.2
#  pass_days = 100
# Results Before Tunning:
#  Test Set RMSE: 0.0017
#
# Results After Tunning:
#  Test Set RMSE: 0.0246
#
# -1349.0% Improvement

# %%
hist.iloc[0, :-2]
# Out:
# 0    False
# 1    False
# 2    False
# 3      256
# 4       32
# 5      0.2
# 6      100
# Name: 3, dtype: object

# %%
first_add_layer, second_add_layer, third_add_layer, n_neurons, n_batch_size, dropout, pass_days = list(hist.iloc[0, :-2])

# %%
print(first_add_layer, second_add_layer, third_add_layer, n_neurons, n_batch_size, dropout, pass_days)
# Out:
# False False False 256 32 0.2 100

# %%
x_train.shape
# Out:
# (2995, 50, 19)

# %%
model = Sequential()
model.add(LSTM(units = n_neurons, 
               return_sequences = True,
               input_shape = (x_train.shape[1],
                             x_train.shape[2])))
model.add(Dropout(dropout))

model.add(LSTM(units = n_neurons, return_sequences = False))
model.add(Dropout(dropout))
model.add(Dense(units = 1, activation = 'linear'))
model.compile(optimizer = 'adam', loss = 'mse')

es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 7)

file_path = 'best_model.h5'

mc = ModelCheckpoint(file_path, monitor = 'val_loss', mode = 'min', verbose = 1, save_best_only = True)

model.fit(x_train, y_train, 
          validation_split = 0.1, 
          epochs = 50, batch_size = n_batch_size,
         callbacks = [es, mc], verbose = 0)
# Out:
# Epoch 1: val_loss improved from inf to 0.00207, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.00207 to 0.00181, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.00181
#
# Epoch 4: val_loss did not improve from 0.00181
#
# Epoch 5: val_loss did not improve from 0.00181
#
# Epoch 6: val_loss improved from 0.00181 to 0.00142, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.00142 to 0.00140, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.00140
#
# Epoch 9: val_loss did not improve from 0.00140
#
# Epoch 10: val_loss did not improve from 0.00140
#
# Epoch 11: val_loss did not improve from 0.00140
#
# Epoch 12: val_loss did not improve from 0.00140
#
# Epoch 13: val_loss did not improve from 0.00140
#
# Epoch 14: val_loss did not improve from 0.00140
# Epoch 14: early stopping

# %%
y_pred = model.predict(x_test)

plt.plot(y_test, color = 'blue', label = 'Test')
plt.plot(y_pred, color = 'red', label = 'pred')
plt.legend()
plt.show()
# Out:
# 11/11 [==============================] - 3s 189ms/step

# %%
MAPE(y_test, y_pred), MAE(y_test, y_pred), RMSE(y_test, y_pred)
# Out:
# (7.088618795631973, 0.03899810661123205, 0.0473375253879844)
