# %% [markdown]
# ## 1. importing packages

# %%
import pandas as pd
import pandas_ta as ta
import numpy as np
import datetime as dt
import pandas_datareader as web
from tqdm import tqdm
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import matplotlib.ticker as ticker
import itertools

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV

import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate
from tensorflow.keras.callbacks import History, EarlyStopping
from tensorflow.keras import optimizers

import keras_tuner as kt
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## 2. overall configurations

# %%
# %matplotlib inline


tqdm.pandas()
sns.set(style='whitegrid',palette='muted')
rcParams['figure.figsize'] = 14, 10

# %% [markdown]
# ## 3. Getting the Data

# %%
import yfinance as yf
ticket = yf.Ticker('BOVA11.SA')
start = dt.datetime(2009, 1, 2) # First register data
end = dt.datetime(dt.datetime.now().year,dt.datetime.now().month,dt.datetime.now().day - 2)

bova11 = ticket.history(interval= '1d', start = start, end = end).reset_index()
bova11
bova11_copy = bova11.copy()

# %%
len(bova11)
# Out:
# 3489

# %% [markdown]
# ## 4. Pre-processing

# %% [markdown]
# Adjust the columns name and type

# %%
bova11.columns = bova11.columns.str.lower()

# %%
bova11.date = pd.to_datetime(bova11.date)

# %%
bova11.isna().sum()
# Out:
# date            0
# open            0
# high            0
# low             0
# close           0
# volume          0
# dividends       0
# stock splits    0
# dtype: int64

# %% [markdown]
# Removing rows with volume 0

# %%
bova11 = bova11.loc[(bova11.volume != 0)].reset_index()
bova11.drop(columns='index', axis = 1, inplace = True)
bova11
# Out:
#                           date        open        high         low  \
# 0    2009-01-02 00:00:00-02:00   38.279999   40.320000   37.939999
# 1    2009-01-05 00:00:00-02:00   40.200001   42.000000   39.700001
# 2    2009-01-06 00:00:00-02:00   42.060001   42.320000   41.549999
# 3    2009-01-07 00:00:00-02:00   41.750000   41.770000   40.450001
# 4    2009-01-08 00:00:00-02:00   40.150002   42.200001   40.150002
# ...                        ...         ...         ...         ...
# 3391 2023-01-17 00:00:00-03:00  106.239998  107.980003  106.220001
# 3392 2023-01-18 00:00:00-03:00  108.830002  109.599998  108.330002
# 3393 2023-01-19 00:00:00-03:00  107.699997  109.540001  107.610001
# 3394 2023-01-20 00:00:00-03:00  109.110001  109.150002  108.010002
# 3395 2023-01-23 00:00:00-03:00  108.889999  109.330002  107.879997
#
#            close   volume  dividends  stock splits
# 0      40.320000   119900          0             0
# 1      42.000000   341700          0             0
# 2      42.320000   178300          0             0
# 3      40.639999    73400          0             0
# 4      42.200001   195300          0             0
# ...          ...      ...        ...           ...
# 3391  107.800003  6647627          0             0
# 3392  108.330002  9405455          0             0
# 3393  109.110001  4378786          0             0
# 3394  108.449997  6287159          0             0
# 3395  107.900002  4401425          0             0
#
# [3396 rows x 8 columns]

# %% [markdown]
# Sorting the data by date

# %%
bova11 = bova11.sort_values(by='date').reset_index(drop=True)

# %% [markdown]
# Adding a column with the previous close value

# %%
bova11["prev_close"] = bova11.shift(1)["close"]

# %%
bova11.head()
# Out:
#                        date       open       high        low      close  \
# 0 2009-01-02 00:00:00-02:00  38.279999  40.320000  37.939999  40.320000
# 1 2009-01-05 00:00:00-02:00  40.200001  42.000000  39.700001  42.000000
# 2 2009-01-06 00:00:00-02:00  42.060001  42.320000  41.549999  42.320000
# 3 2009-01-07 00:00:00-02:00  41.750000  41.770000  40.450001  40.639999
# 4 2009-01-08 00:00:00-02:00  40.150002  42.200001  40.150002  42.200001
#
#    volume  dividends  stock splits  prev_close
# 0  119900          0             0         NaN
# 1  341700          0             0   40.320000
# 2  178300          0             0   42.000000
# 3   73400          0             0   42.320000
# 4  195300          0             0   40.639999

# %% [markdown]
# Adding the close difference between dates

# %%
bova11["close_change"]= bova11.progress_apply(
    lambda row: 0 if np.isnan(row.prev_close) else row.close - row.prev_close,
    axis = 1
)
# Out:
# 100%|██████████| 3396/3396 [00:00<00:00, 10382.37it/s]

# %%
bova11.head()
# Out:
#                        date       open       high        low      close  \
# 0 2009-01-02 00:00:00-02:00  38.279999  40.320000  37.939999  40.320000
# 1 2009-01-05 00:00:00-02:00  40.200001  42.000000  39.700001  42.000000
# 2 2009-01-06 00:00:00-02:00  42.060001  42.320000  41.549999  42.320000
# 3 2009-01-07 00:00:00-02:00  41.750000  41.770000  40.450001  40.639999
# 4 2009-01-08 00:00:00-02:00  40.150002  42.200001  40.150002  42.200001
#
#    volume  dividends  stock splits  prev_close  close_change
# 0  119900          0             0         NaN      0.000000
# 1  341700          0             0   40.320000      1.680000
# 2  178300          0             0   42.000000      0.320000
# 3   73400          0             0   42.320000     -1.680000
# 4  195300          0             0   40.639999      1.560001

# %% [markdown]
# Checking the dataseries over time

# %%
daily_closing = bova11[['date','close']]
daily_closing = daily_closing.set_index('date')
ax = daily_closing.plot()
plt.title('Valor de fechamento do BOVA11 ao longo dos anos')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R${x:,.2f}"))

# %% [markdown]
# #### Feature Engineering
# Add auxiliar columns that can improve our model, like moving averages,standard deviation, techinical indicators and others
# Let's add:
# - Moving_average for 3, 10, 30 and 60 days
# - Standard deviation for 7, 30 and 60 days
# - Bollinger limits for Upper and lowers 3, 30 and 60
# - Add RSI indicator

# %%
# Adding move Averages columns
bova11['ma_3d'] = bova11['close'].rolling(3, center = True, min_periods=1).mean()
bova11['ma_10d'] = bova11['close'].rolling(10, center = True,min_periods=1).mean()
bova11['ma_30d'] = bova11['close'].rolling(30, center=True, min_periods=1).mean()
bova11['ma_60d'] = bova11['close'].rolling(60, center = True, min_periods = 1).mean()

# %%
# Adding standard deviation columns
bova11['std_7'] = bova11['close'].rolling(7, center = True, min_periods = 1).std()
bova11['std_30'] = bova11['close'].rolling(30, center = True, min_periods = 1).std()
bova11['std_60'] = bova11['close'].rolling(60, center = True, min_periods = 1).std()

# %%
# Adding the bollinger bands
bova11['upper3'] = bova11['ma_3d'] + 2*bova11['close'].rolling(3, center = True, min_periods = 1).std()
bova11['lower3'] = bova11['ma_3d'] - 2*bova11['close'].rolling(3, center = True, min_periods = 1).std()

bova11['upper30'] = bova11['ma_30d'] + 2*bova11['std_30']
bova11['lower30'] = bova11['ma_30d'] - 2*bova11['std_30']

bova11['upper60'] = bova11['ma_60d'] + 2*bova11['std_60']
bova11['lower60'] = bova11['ma_60d'] - 2*bova11['std_60']

# Adding tecnical indicator RSI
bova11['RSI'] = ta.rsi(bova11['close'], length = 15)

# %%
moving_avg = bova11[['date','ma_30d']]
moving_avg = moving_avg.set_index('date')
ax = moving_avg.plot()
plt.title('Valor de fechamento do IBOVESPA ao longo dos anos')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R${x:,.2f}"))

# %% [markdown]
# Select the features and the predict columns

# %%
bova11.drop(['date', 'volume', 'dividends', 'stock splits', 'prev_close'],
            axis = 1,
           inplace = True)

# %%
bova11
# Out:
#             open        high         low       close  close_change  \
# 0      38.279999   40.320000   37.939999   40.320000      0.000000
# 1      40.200001   42.000000   39.700001   42.000000      1.680000
# 2      42.060001   42.320000   41.549999   42.320000      0.320000
# 3      41.750000   41.770000   40.450001   40.639999     -1.680000
# 4      40.150002   42.200001   40.150002   42.200001      1.560001
# ...          ...         ...         ...         ...           ...
# 3391  106.239998  107.980003  106.220001  107.800003      2.330002
# 3392  108.830002  109.599998  108.330002  108.330002      0.529999
# 3393  107.699997  109.540001  107.610001  109.110001      0.779999
# 3394  109.110001  109.150002  108.010002  108.449997     -0.660004
# 3395  108.889999  109.330002  107.879997  107.900002     -0.549995
#
#            ma_3d      ma_10d      ma_30d      ma_60d     std_7    std_30  \
# 0      41.160000   41.496000   40.072667   40.216334  0.987387  1.459904
# 1      41.546666   41.580000   39.948125   40.269033  0.941319  1.495795
# 2      41.653333   41.311429   39.892353   40.322813  0.866718  1.466439
# 3      41.720000   41.147500   39.842223   40.313031  1.063445  1.438465
# 4      41.613333   40.801111   39.897895   40.303530  1.118613  1.418844
# ...          ...         ...         ...         ...       ...       ...
# 3391  107.200002  107.895000  106.095000  104.821429  1.173199  2.413782
# 3392  108.413335  107.974445  106.144737  104.797647  1.158716  2.469373
# 3393  108.630000  107.833751  106.213889  104.738788  1.252767  2.521963
# 3394  108.486666  107.772858  106.179411  104.712188  0.521506  2.595204
# 3395  108.174999  107.843334  106.193750  104.749033  0.500824  2.679619
#
#         std_60      upper3      lower3     upper30     lower30     upper60  \
# 0     1.394817   43.535879   38.784121   42.992476   37.152858   43.005967
# 1     1.402411   43.695279   39.398054   42.939715   36.956536   43.073854
# 2     1.412751   43.437411   39.869255   42.825231   36.959475   43.148315
# 3     1.391637   43.594461   39.845539   42.719153   36.965292   43.096304
# 4     1.371508   43.311019   39.915647   42.735582   37.060208   43.046547
# ...        ...         ...         ...         ...         ...         ...
# 3391  2.774482  110.242962  104.157042  110.922564  101.267436  110.370393
# 3392  2.812583  109.731260  107.095410  111.083484  101.205990  110.422813
# 3393  2.834847  109.470000  107.789999  111.257815  101.169963  110.408483
# 3394  2.876020  109.698331  107.275002  111.369819  100.989004  110.464229
# 3395  2.915874  108.952810  107.397188  111.552989  100.834511  110.580781
#
#         lower60        RSI
# 0     37.426700        NaN
# 1     37.464211        NaN
# 2     37.497311        NaN
# 3     37.529757        NaN
# 4     37.560513        NaN
# ...         ...        ...
# 3391  99.272464  55.489642
# 3392  99.172482  56.605212
# 3393  99.069094  58.254979
# 3394  98.960147  56.314016
# 3395  98.917285  54.687174
#
# [3396 rows x 19 columns]

# %%
bova11['target'] = bova11.close - bova11.open
#bova11['targetClass'] = [1 if bova11.target[i] > 0 else 0 for i in range(len(bova11))]
bova11['targetNextClose'] = bova11['close'].shift(-1)

# %%
bova11
# Out:
#             open        high         low       close  close_change  \
# 0      38.279999   40.320000   37.939999   40.320000      0.000000
# 1      40.200001   42.000000   39.700001   42.000000      1.680000
# 2      42.060001   42.320000   41.549999   42.320000      0.320000
# 3      41.750000   41.770000   40.450001   40.639999     -1.680000
# 4      40.150002   42.200001   40.150002   42.200001      1.560001
# ...          ...         ...         ...         ...           ...
# 3391  106.239998  107.980003  106.220001  107.800003      2.330002
# 3392  108.830002  109.599998  108.330002  108.330002      0.529999
# 3393  107.699997  109.540001  107.610001  109.110001      0.779999
# 3394  109.110001  109.150002  108.010002  108.449997     -0.660004
# 3395  108.889999  109.330002  107.879997  107.900002     -0.549995
#
#            ma_3d      ma_10d      ma_30d      ma_60d     std_7  ...    std_60  \
# 0      41.160000   41.496000   40.072667   40.216334  0.987387  ...  1.394817
# 1      41.546666   41.580000   39.948125   40.269033  0.941319  ...  1.402411
# 2      41.653333   41.311429   39.892353   40.322813  0.866718  ...  1.412751
# 3      41.720000   41.147500   39.842223   40.313031  1.063445  ...  1.391637
# 4      41.613333   40.801111   39.897895   40.303530  1.118613  ...  1.371508
# ...          ...         ...         ...         ...       ...  ...       ...
# 3391  107.200002  107.895000  106.095000  104.821429  1.173199  ...  2.774482
# 3392  108.413335  107.974445  106.144737  104.797647  1.158716  ...  2.812583
# 3393  108.630000  107.833751  106.213889  104.738788  1.252767  ...  2.834847
# 3394  108.486666  107.772858  106.179411  104.712188  0.521506  ...  2.876020
# 3395  108.174999  107.843334  106.193750  104.749033  0.500824  ...  2.915874
#
#           upper3      lower3     upper30     lower30     upper60    lower60  \
# 0      43.535879   38.784121   42.992476   37.152858   43.005967  37.426700
# 1      43.695279   39.398054   42.939715   36.956536   43.073854  37.464211
# 2      43.437411   39.869255   42.825231   36.959475   43.148315  37.497311
# 3      43.594461   39.845539   42.719153   36.965292   43.096304  37.529757
# 4      43.311019   39.915647   42.735582   37.060208   43.046547  37.560513
# ...          ...         ...         ...         ...         ...        ...
# 3391  110.242962  104.157042  110.922564  101.267436  110.370393  99.272464
# 3392  109.731260  107.095410  111.083484  101.205990  110.422813  99.172482
# 3393  109.470000  107.789999  111.257815  101.169963  110.408483  99.069094
# 3394  109.698331  107.275002  111.369819  100.989004  110.464229  98.960147
# 3395  108.952810  107.397188  111.552989  100.834511  110.580781  98.917285
#
#             RSI    target  targetNextClose
# 0           NaN  2.040001        42.000000
# 1           NaN  1.799999        42.320000
# 2           NaN  0.259998        40.639999
# 3           NaN -1.110001        42.200001
# 4           NaN  2.049999        42.000000
# ...         ...       ...              ...
# 3391  55.489642  1.560005       108.330002
# 3392  56.605212 -0.500000       109.110001
# 3393  58.254979  1.410004       108.449997
# 3394  56.314016 -0.660004       107.900002
# 3395  54.687174 -0.989998              NaN
#
# [3396 rows x 21 columns]

# %%
bova11.dropna(inplace = True)

# %%
scaler = MinMaxScaler(feature_range = (-1, 1))
bova11_scaled = scaler.fit_transform(bova11)
print(bova11_scaled)
# Out:
# [[-0.41052802 -0.95937954 -0.97594966 ... -0.34158244 -0.812735
#   -0.94288915]
#  [-0.39380423 -0.93549828 -0.95100022 ... -0.1145866  -0.81635782
#   -0.94311308]
#  [-0.38663696 -0.9468809  -0.94178467 ... -0.11645738 -0.82917641
#   -0.90033593]
#  ...
#  [ 0.73337584  0.6290592   0.63182744 ...  0.2455929  -0.85648596
#    0.62732364]
#  [ 0.71537783  0.62772012  0.615644   ...  0.29514399 -0.80326028
#    0.61254192]
#  [ 0.73783548  0.61901574  0.62463482 ...  0.23684678 -0.86094475
#    0.60022399]]

# %% [markdown]
# Select the features and prediction target columns

# %% [markdown]
# ### 6. Calculating Error metrics

# %%
def MAPE(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    MAPE = np.nanmean(np.abs((actual - pred) / actual)) * 100
    return MAPE

def MAE(actual, pred):
    MAE = mean_absolute_error(actual, pred)
    return MAE

def RMSE(actual, pred):
    RMSE = mean_squared_error(actual, pred, squared = False)
    return RMSE

# %%
n_neurons = 256
n_batch_size = 32
dropout = 0.2
pass_days = 100

# %%
backcandles = pass_days
X = []
for j in range(19): # range is the number of feature columns you will use
    X.append([])
    for k in range(backcandles, bova11_scaled.shape[0]):
        X[j].append(bova11_scaled[k-backcandles:k, j])

#move axis from 0 to position 2
X = np.moveaxis(X, [0], [2])

X, yi = np.array(X), np.array(bova11_scaled[backcandles:, -1]) # Chosing the last column as the pred. target
y = np.reshape(yi, (len(yi), 1))

splitlimit = int(len(X) * 0.9)
x_train, x_test = X[:splitlimit], X[splitlimit+1:]
y_train, y_test = y[:splitlimit], y[splitlimit+1:]

# %%
model = Sequential()
model.add(LSTM(units = n_neurons, 
               return_sequences = True,
               input_shape = (x_train.shape[1],
                             x_train.shape[2])))
model.add(Dropout(dropout))

model.add(LSTM(units = n_neurons, return_sequences = False))
model.add(Dropout(dropout))
model.add(Dense(units = 1, activation = 'linear'))
model.compile(optimizer = 'adam', loss = 'mse')

es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 7)

file_path = 'best_model.h5'

mc = ModelCheckpoint(file_path, monitor = 'val_loss', mode = 'min', verbose = 1, save_best_only = True)

model.fit(x_train, y_train, 
          validation_split = 0.1, 
          epochs = 50, batch_size = n_batch_size,
         callbacks = [es, mc], verbose = 0)
# Out:
# Epoch 1: val_loss improved from inf to 0.00246, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.00246 to 0.00243, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.00243 to 0.00237, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.00237 to 0.00194, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 0.00194 to 0.00145, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.00145
#
# Epoch 7: val_loss did not improve from 0.00145
#
# Epoch 8: val_loss did not improve from 0.00145
#
# Epoch 9: val_loss did not improve from 0.00145
#
# Epoch 10: val_loss did not improve from 0.00145
#
# Epoch 11: val_loss did not improve from 0.00145
#
# Epoch 12: val_loss did not improve from 0.00145
# Epoch 12: early stopping

# %%
y_pred = model.predict(x_test)

plt.plot(y_test, color = 'blue', label = 'Test')
plt.plot(y_pred, color = 'red', label = 'pred')
plt.legend()
plt.show()
# Out:
# 11/11 [==============================] - 6s 345ms/step

# %%
MAE(y_test,y_pred), MAPE(y_test, y_pred), RMSE(y_test, y_pred)
# Out:
# (0.038340434900836246, 7.021754932729224, 0.046314301612468446)

# %% [markdown]
# ### 2. try a different method:
# - Separete the last 90 values from the bova_11 values
# - Format them with the same features as the prediction
# - Do the predict on the next value
# - invert the transformation to get the original values
# - Recreate the dataframe with the same values and the prediction value
# - Complete all the feature columns for the next input to predict
# - make the next prediction
# - put it into a for loop for n days
# - predict for 1,5,30 and 90 days
# - calculate the error metrics from all the predictions

# %%
teste = bova11.copy()

# %%
teste.reset_index(drop = True, inplace = True)

# %%
scaler = MinMaxScaler(feature_range = (-1, 1))
teste_scaled = scaler.fit_transform(teste)
print(teste_scaled)
# Out:
# [[-0.41052802 -0.95937954 -0.97594966 ... -0.34158244 -0.812735
#   -0.94288915]
#  [-0.39380423 -0.93549828 -0.95100022 ... -0.1145866  -0.81635782
#   -0.94311308]
#  [-0.38663696 -0.9468809  -0.94178467 ... -0.11645738 -0.82917641
#   -0.90033593]
#  ...
#  [ 0.73337584  0.6290592   0.63182744 ...  0.2455929  -0.85648596
#    0.62732364]
#  [ 0.71537783  0.62772012  0.615644   ...  0.29514399 -0.80326028
#    0.61254192]
#  [ 0.73783548  0.61901574  0.62463482 ...  0.23684678 -0.86094475
#    0.60022399]]

# %%
backcandles = pass_days
X = []
for j in range(19): # range is the number of feature columns you will use
    X.append([])
    for k in range(backcandles, teste_scaled.shape[0]):
        X[j].append(teste_scaled[k-backcandles:k, j])

#move axis from 0 to position 2
X = np.moveaxis(X, [0], [2])

X, yi = np.array(X), np.array(teste_scaled[backcandles:, -1]) # Chosing the last column as the pred. target
y = np.reshape(yi, (len(yi), 1))

splitlimit = int(len(X) * 0.9)
x_train, x_test = X[:splitlimit], X[splitlimit+1:]
y_train, y_test = y[:splitlimit], y[splitlimit+1:]

teste_features = (x_test[len(x_test)-99:])

# %%
feature_predict = model.predict(teste_features)
# Out:
# 4/4 [==============================] - 1s 256ms/step

# %%
feature_predict[0]
# Out:
# array([0.5661399], dtype=float32)

# %%
teste_scaled[(len(teste_scaled) - 99)][-1] = feature_predict[0]

# %%
pred_value_teste = scaler.inverse_transform(teste_scaled)[(len(teste_scaled) - 99)][-1]

# %%
pred_value_teste
# Out:
# 106.37814566652207

# %%
teste.iloc[len(teste) - 99][-1] = pred_value_teste
# Out:
# C:\Users\PC Casa\AppData\Local\Temp\ipykernel_14164\983886092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste.iloc[len(teste) - 99][-1] = pred_value_teste

# %%
teste.loc[len(teste)-99+1:len(teste)-99+1, 'close'] = pred_value_teste

# %%
# Adding close change

teste["prev_close"] = teste.shift(1)["close"]

teste["close_change"]= teste.progress_apply(
    lambda row: 0 if np.isnan(row.prev_close) else row.close - row.prev_close,
    axis = 1
)

# Adding move Averages columns
teste['ma_3d'] = teste['close'].rolling(3, center = True, min_periods=1).mean()
teste['ma_10d'] = teste['close'].rolling(10, center = True,min_periods=1).mean()
teste['ma_30d'] = teste['close'].rolling(30, center=True, min_periods=1).mean()
teste['ma_60d'] = teste['close'].rolling(60, center = True, min_periods = 1).mean()

# Adding standard deviation columns
teste['std_7'] = teste['close'].rolling(7, center = True, min_periods = 1).std()
teste['std_30'] = teste['close'].rolling(30, center = True, min_periods = 1).std()
teste['std_60'] = teste['close'].rolling(60, center = True, min_periods = 1).std()

# Adding the bollinger bands
teste['upper3'] = teste['ma_3d'] + 2*teste['close'].rolling(3, center = True, min_periods = 1).std()
teste['lower3'] = teste['ma_3d'] - 2*teste['close'].rolling(3, center = True, min_periods = 1).std()

teste['upper30'] = teste['ma_30d'] + 2*teste['std_30']
teste['lower30'] = teste['ma_30d'] - 2*teste['std_30']

teste['upper60'] = teste['ma_60d'] + 2*teste['std_60']
teste['lower60'] = teste['ma_60d'] - 2*teste['std_60']

# Adding tecnical indicator RSI
teste['RSI'] = ta.rsi(teste['close'], length = 15)

teste['target'] = teste.close - teste.open
#teste['targetClass'] = [1 if teste.target[i] > 0 else 0 for i in range(len(teste))]
teste['targetNextClose'] = teste['close'].shift(-1)
# Out:
# 100%|██████████| 3380/3380 [00:00<00:00, 14022.47it/s]

# %%
teste.tail(99)
# Out:
#             open        high         low       close  close_change  \
# 3281  108.699997  108.900002  106.250000  106.400002     -2.000000
# 3282  106.830002  107.519997  105.699997  106.378146     -0.021856
# 3283  106.070000  106.589996  104.430000  106.589996      0.211851
# 3284  107.360001  108.419998  106.709999  107.089996      0.500000
# 3285  108.269997  108.690002  107.779999  108.449997      1.360001
# ...          ...         ...         ...         ...           ...
# 3375  106.949997  106.949997  105.129997  105.470001     -1.879997
# 3376  106.239998  107.980003  106.220001  107.800003      2.330002
# 3377  108.830002  109.599998  108.330002  108.330002      0.529999
# 3378  107.699997  109.540001  107.610001  109.110001      0.779999
# 3379  109.110001  109.150002  108.010002  108.449997     -0.660004
#
#            ma_3d      ma_10d      ma_30d      ma_60d     std_7  ...    std_60  \
# 3281  107.059383  107.954814  107.702605  105.787469  1.252325  ...  4.958909
# 3282  106.456048  107.639813  107.806271  106.046802  0.984717  ...  4.772613
# 3283  106.686046  107.339813  107.925271  106.267969  1.006511  ...  4.552037
# 3284  107.376663  107.219814  107.990605  106.510469  0.841670  ...  4.343322
# 3285  107.163330  107.327814  107.873605  106.785802  1.032804  ...  4.147565
# ...          ...         ...         ...         ...       ...  ...       ...
# 3375  106.873334  107.640000  106.000000  104.822857  1.253923  ...  2.776126
# 3376  107.200002  107.894445  106.000000  104.730883  1.173199  ...  2.763217
# 3377  108.413335  107.983750  106.047222  104.703637  1.267823  ...  2.801419
# 3378  108.630000  107.824286  106.114706  104.640000  1.400292  ...  2.821907
# 3379  108.779999  107.751667  106.071875  104.609355  0.538353  ...  2.863135
#
#           upper3      lower3     upper30     lower30     upper60    lower60  \
# 3281  109.381505  104.737260  110.644298  104.760911  115.705288  95.869650
# 3282  106.689081  106.223015  110.575283  105.037260  115.592029  96.501576
# 3283  107.417078  105.955014  110.778231  105.072312  115.372042  97.163896
# 3284  109.301796  105.451530  110.737555  105.243655  115.197114  97.823825
# 3285  109.666555  104.660105  110.799288  104.947921  115.080932  98.490673
# ...          ...         ...         ...         ...         ...        ...
# 3375  109.345284  104.401385  110.752196  101.247804  110.375110  99.270605
# 3376  110.242962  104.157042  110.882418  101.117582  110.257317  99.204448
# 3377  109.731260  107.095410  111.053298  101.041146  110.306474  99.100799
# 3378  109.470000  107.789999  111.240982  100.988429  110.283814  98.996186
# 3379  109.713385  107.846613  111.353689  100.790060  110.335626  98.883084
#
#             RSI    target  targetNextClose
# 3281  54.919330 -2.299995       106.378146
# 3282  54.833368 -0.451856       106.589996
# 3283  55.555844  0.519997       107.089996
# 3284  57.283683 -0.270004       108.449997
# 3285  61.630821  0.180000       105.949997
# ...         ...       ...              ...
# 3375  50.240844 -1.479996       107.800003
# 3376  55.489938  1.560005       108.330002
# 3377  56.605585 -0.500000       109.110001
# 3378  58.255459  1.410004       108.449997
# 3379  56.314343 -0.660004              NaN
#
# [99 rows x 21 columns]

# %%
teste.drop(axis = 1, columns = 'prev_close', inplace = True)

# %%
def predict(df, days):
    
    #copia do df para editar
    df_ = df.copy()
    # converter em escala pro modelo
    scaler = MinMaxScaler(feature_range = (-1, 1))
    df_scaled = scaler.fit_transform(df)
    
    #pegar os ultimos dias para predição
    backcandles = pass_days
    X = []
    for j in range(19): # range is the number of feature columns you will use
        X.append([])
        for k in range(backcandles, df_scaled.shape[0]):
            X[j].append(df_scaled[k-backcandles:k, j])

    #move axis from 0 to position 2
    X = np.moveaxis(X, [0], [2])
    
    X, yi = np.array(X), np.array(bova11_scaled[backcandles:, -1]) # Chosing the last column as the pred. target
    y = np.reshape(yi, (len(yi), 1))

    splitlimit = int(len(X) * 0.9)
    x_train, x_test = X[:splitlimit], X[splitlimit+1:]
    y_train, y_test = y[:splitlimit], y[splitlimit+1:]
    
    # Pega os 100 ultimos dias (definido por hyperparametro)
    x_features = x_test[:len(x_test) - passdays]
    
    # realiza a predicao
    feature_predict = model.predict(x_features)

# %%
x_test[:len(x_test) - 100].shape
# Out:
# (227, 100, 19)
